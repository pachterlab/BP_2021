# %%
# !date
# Out:
# Thu Jan 14 14:19:40 PST 2021

# %% [markdown]
# # Salmon index

# %% [markdown]
# ## Human GRCh38

# %%
# %%bash
# time salmon index -i ../../reference/human-grch38/salmon \
#                   -t ../../reference/human-grch38/transcriptome.fa
# Out:
# Threads = 2
# Vertex length = 31
# Hash functions = 5
# Filter size = 2147483648
# Capacity = 2
# Files:
# ../../reference/human-grch38/salmon/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:2147483648
# Pass	Filling	Filtering
# 1	29	55
# 2	5	1
# True junctions count = 651945
# False junctions count = 1207369
# Hash table size = 1859314
# Candidate marks count = 8075425
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 5098137
# Edges construction time: 6
# --------------------------------------------------------------------------------
# Distinct junctions = 651945
#
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# Bitarray       593187584  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# Version Info: This is the most recent version of salmon.
# index ["../../reference/human-grch38/salmon"] did not previously exist  . . . creating it
# [2021-01-14 14:28:12.954] [jLog] [warning] The salmon index is being built without any decoy sequences.  It is recommended that decoy sequence (either computed auxiliary decoy sequence or the genome of the organism) be provided during indexing. Further details can be found at https://salmon.readthedocs.io/en/latest/salmon.html#preparing-transcriptome-indices-mapping-based-mode.
# [2021-01-14 14:28:12.954] [jLog] [info] building index
# out : ../../reference/human-grch38/salmon
# [2021-01-14 14:28:12.954] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-01-14 14:28:15.271] [puff::index::jointLog] [warning] Entry with header [ENST00000415118], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.271] [puff::index::jointLog] [warning] Entry with header [ENST00000434970], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.271] [puff::index::jointLog] [warning] Entry with header [ENST00000448914], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000439842], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000390567], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000452198], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000390569], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000437320], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000390571], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000390572], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000450276], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000390574], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000390575], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000431870], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000390578], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000451044], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000390580], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000390581], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000431440], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000390583], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000390584], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000390585], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000430425], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000454691], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000390588], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000414852], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000390590], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000390591], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.476] [puff::index::jointLog] [warning] Entry with header [ENST00000454908], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.477] [puff::index::jointLog] [warning] Entry with header [ENST00000518246], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.478] [puff::index::jointLog] [warning] Entry with header [ENST00000604642], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.478] [puff::index::jointLog] [warning] Entry with header [ENST00000603326], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.478] [puff::index::jointLog] [warning] Entry with header [ENST00000604950], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.478] [puff::index::jointLog] [warning] Entry with header [ENST00000603077], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.478] [puff::index::jointLog] [warning] Entry with header [ENST00000605284], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.478] [puff::index::jointLog] [warning] Entry with header [ENST00000604446], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.478] [puff::index::jointLog] [warning] Entry with header [ENST00000603693], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.478] [puff::index::jointLog] [warning] Entry with header [ENST00000603935], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.478] [puff::index::jointLog] [warning] Entry with header [ENST00000604102], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:15.478] [puff::index::jointLog] [warning] Entry with header [ENST00000604838], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:28:19.506] [puff::index::jointLog] [warning] Entry with header [ENST00000632684], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2021-01-14 14:28:20.290] [puff::index::jointLog] [warning] Removed 321 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-14 14:28:20.290] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2021-01-14 14:28:20.290] [puff::index::jointLog] [info] Replaced 0 non-ATCG nucleotides
# [2021-01-14 14:28:20.290] [puff::index::jointLog] [info] Clipped poly-A tails from 1,426 transcripts
# wrote 172557 cleaned references
# [2021-01-14 14:28:20.934] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2021-01-14 14:28:23.126] [puff::index::jointLog] [info] ntHll estimated 112142705 distinct k-mers, setting filter size to 2^31
# allowedIn: 15
# Max Junction ID: 759869
# seen.size():6078961 kmerInfo.size():759870
# approximateContigTotalLength: 79845466
# counters for complex kmers:
# (prec>1 & succ>1)=46120 | (succ>1 & isStart)=689 | (prec>1 & isEnd)=595 | (isStart & isEnd)=81
# contig count: 975705 element count: 142480698 complex nodes: 47485
# # of ones in rank vector: 975704
# [2021-01-14 14:30:18.588] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2021-01-14 14:30:18.588] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory ../../reference/human-grch38/salmon
# size = 142480698
# -----------------------------------------
# | Loading contigs | Time = 14.253 ms
# -----------------------------------------
# size = 142480698
# -----------------------------------------
# | Loading contig boundaries | Time = 6.4472 ms
# -----------------------------------------
# Number of ones: 975704
# Number of ones per inventory item: 512
# Inventory entries filled: 1906
# 975704
# [2021-01-14 14:30:18.913] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2021-01-14 14:30:18.921] [puff::index::jointLog] [info] contig count for validation: 975,704
# [2021-01-14 14:30:19.269] [puff::index::jointLog] [info] Total # of Contigs : 975,704
# [2021-01-14 14:30:19.269] [puff::index::jointLog] [info] Total # of numerical Contigs : 975,704
# [2021-01-14 14:30:19.310] [puff::index::jointLog] [info] Total # of contig vec entries: 5,087,877
# [2021-01-14 14:30:19.310] [puff::index::jointLog] [info] bits per offset entry 23
# [2021-01-14 14:30:19.425] [puff::index::jointLog] [info] Done constructing the contig vector. 975705
# [2021-01-14 14:30:19.775] [puff::index::jointLog] [info] # segments = 975,704
# [2021-01-14 14:30:19.775] [puff::index::jointLog] [info] total length = 142,480,698
# [2021-01-14 14:30:19.825] [puff::index::jointLog] [info] Reading the reference files ...
# [2021-01-14 14:30:20.498] [puff::index::jointLog] [info] positional integer width = 28
# [2021-01-14 14:30:20.498] [puff::index::jointLog] [info] seqSize = 142,480,698
# [2021-01-14 14:30:20.498] [puff::index::jointLog] [info] rankSize = 142,480,698
# [2021-01-14 14:30:20.498] [puff::index::jointLog] [info] edgeVecSize = 0
# [2021-01-14 14:30:20.498] [puff::index::jointLog] [info] num keys = 113,209,578
# [Building BooPHF]  100  %   elapsed:   0 min 10 sec   remaining:   0 min 0  sec
# [2021-01-14 14:30:30.673] [puff::index::jointLog] [info] mphf size = 70.7135 MB
# [2021-01-14 14:30:30.781] [puff::index::jointLog] [info] chunk size = 71,240,349
# [2021-01-14 14:30:30.781] [puff::index::jointLog] [info] chunk 0 = [0, 71,240,349)
# [2021-01-14 14:30:30.781] [puff::index::jointLog] [info] chunk 1 = [71,240,349, 142,480,668)
# [2021-01-14 14:30:44.042] [puff::index::jointLog] [info] finished populating pos vector
# [2021-01-14 14:30:44.042] [puff::index::jointLog] [info] writing index components
# [2021-01-14 14:30:44.488] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2021-01-14 14:30:44.562] [jLog] [info] done building index
#
# real	2m36.645s
# user	5m59.013s
# sys	0m4.061s

# %% [markdown]
# ## Human-mouse hg19-mm10

# %%
# %%bash
# time salmon index -i ../../reference/human_mouse-hg19_mm10/salmon \
#                   -t ../../reference/human_mouse-hg19_mm10/transcriptome.fa
# Out:
# Threads = 2
# Vertex length = 31
# Hash functions = 5
# Filter size = 4294967296
# Capacity = 2
# Files:
# ../../reference/human_mouse-hg19_mm10/salmon/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:4294967296
# Pass	Filling	Filtering
# 1	59	118
# 2	9	0
# True junctions count = 1462789
# False junctions count = 1378139
# Hash table size = 2840928
# Candidate marks count = 13340479
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 1
# True marks count: 10944688
# Edges construction time: 9
# --------------------------------------------------------------------------------
# Distinct junctions = 1462789
#
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# Bitarray      1218011008  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# Version Info: This is the most recent version of salmon.
# index ["../../reference/human_mouse-hg19_mm10/salmon"] did not previously exist  . . . creating it
# [2021-01-14 14:30:49.648] [jLog] [warning] The salmon index is being built without any decoy sequences.  It is recommended that decoy sequence (either computed auxiliary decoy sequence or the genome of the organism) be provided during indexing. Further details can be found at https://salmon.readthedocs.io/en/latest/salmon.html#preparing-transcriptome-indices-mapping-based-mode.
# [2021-01-14 14:30:49.648] [jLog] [info] building index
# out : ../../reference/human_mouse-hg19_mm10/salmon
# [2021-01-14 14:30:49.648] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-01-14 14:30:50.259] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000594394], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:50.568] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000606517], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:50.882] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000598940], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.427] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000598624], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.530] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000543745], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.704] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000415118], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.704] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000434970], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.704] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000448914], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000439842], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390567], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000452198], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390569], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000437320], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390571], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390572], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000450276], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390574], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390575], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000431870], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390578], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000451044], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390580], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390581], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000431440], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390583], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390584], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390585], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000430425], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000454691], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390588], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000414852], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390590], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390591], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.991] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000454908], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.992] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000518246], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.993] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000604642], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.993] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000603326], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.993] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000604950], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.993] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000603077], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.993] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000605284], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.996] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000604446], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.996] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000603693], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.996] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000603935], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.996] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000604102], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:51.996] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000604838], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:52.331] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000602572], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:52.793] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000579054], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:53.954] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000595481], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:55.112] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000473810], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:55.213] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000603775], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:57.300] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000191703], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.464] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000179520], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.464] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000179883], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.464] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000195858], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.464] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000179932], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.464] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000180001], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.464] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178815], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.464] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000177965], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.464] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178909], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.464] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000177646], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.464] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178230], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.464] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178483], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.464] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000179262], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.464] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178549], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.464] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000193012], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.464] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000179166], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.465] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000179560], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.465] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178902], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.465] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000192089], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.465] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000177839], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.465] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000170385], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.465] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000103439], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.465] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000180266], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.465] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178811], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.465] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000103441], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.678] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000231713], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.678] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000231466], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.723] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000226589], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.745] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000228114], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.762] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000226226], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.810] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000196221], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.810] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000179664], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.810] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000177564], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.811] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000103739], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:58.891] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000226961], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:59.000] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000227223], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:59.070] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000226615], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:59.291] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000226153], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:59.325] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000227002], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:59.357] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000226172], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:30:59.880] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000229312], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:31:00.734] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000179793], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:31:01.045] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000200713], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:31:01.316] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178537], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:31:01.316] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178862], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:31:02.237] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000165700], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2021-01-14 14:31:02.836] [puff::index::jointLog] [warning] Removed 3127 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-14 14:31:02.836] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2021-01-14 14:31:02.837] [puff::index::jointLog] [info] Replaced 4 non-ATCG nucleotides
# [2021-01-14 14:31:02.837] [puff::index::jointLog] [info] Clipped poly-A tails from 2,163 transcripts
# wrote 329922 cleaned references
# [2021-01-14 14:31:04.157] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2021-01-14 14:31:08.009] [puff::index::jointLog] [info] ntHll estimated 231098312 distinct k-mers, setting filter size to 2^32
# allowedIn: 23
# Max Junction ID: 1723512
# seen.size():13788105 kmerInfo.size():1723513
# approximateContigTotalLength: 159044876
# counters for complex kmers:
# (prec>1 & succ>1)=85743 | (succ>1 & isStart)=1667 | (prec>1 & isEnd)=1695 | (isStart & isEnd)=127
# contig count: 2247156 element count: 299872677 complex nodes: 89232
# # of ones in rank vector: 2247155
# [2021-01-14 14:35:02.232] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2021-01-14 14:35:02.232] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory ../../reference/human_mouse-hg19_mm10/salmon
# size = 299872677
# -----------------------------------------
# | Loading contigs | Time = 27.628 ms
# -----------------------------------------
# size = 299872677
# -----------------------------------------
# | Loading contig boundaries | Time = 13.08 ms
# -----------------------------------------
# Number of ones: 2247155
# Number of ones per inventory item: 512
# Inventory entries filled: 4389
# 2247155
# [2021-01-14 14:35:02.849] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2021-01-14 14:35:02.867] [puff::index::jointLog] [info] contig count for validation: 2,247,155
# [2021-01-14 14:35:03.590] [puff::index::jointLog] [info] Total # of Contigs : 2,247,155
# [2021-01-14 14:35:03.590] [puff::index::jointLog] [info] Total # of numerical Contigs : 2,247,155
# [2021-01-14 14:35:03.707] [puff::index::jointLog] [info] Total # of contig vec entries: 10,961,762
# [2021-01-14 14:35:03.707] [puff::index::jointLog] [info] bits per offset entry 24
# [2021-01-14 14:35:04.016] [puff::index::jointLog] [info] Done constructing the contig vector. 2247156
# [2021-01-14 14:35:04.762] [puff::index::jointLog] [info] # segments = 2,247,155
# [2021-01-14 14:35:04.762] [puff::index::jointLog] [info] total length = 299,872,677
# [2021-01-14 14:35:04.874] [puff::index::jointLog] [info] Reading the reference files ...
# [2021-01-14 14:35:06.065] [puff::index::jointLog] [info] positional integer width = 29
# [2021-01-14 14:35:06.065] [puff::index::jointLog] [info] seqSize = 299,872,677
# [2021-01-14 14:35:06.065] [puff::index::jointLog] [info] rankSize = 299,872,677
# [2021-01-14 14:35:06.065] [puff::index::jointLog] [info] edgeVecSize = 0
# [2021-01-14 14:35:06.065] [puff::index::jointLog] [info] num keys = 232,458,027
# [Building BooPHF]  99.9 %   elapsed:   0 min 23 sec   remaining:   0 min 0  sec
# [2021-01-14 14:35:28.835] [puff::index::jointLog] [info] mphf size = 145.198 MB
# [2021-01-14 14:35:29.051] [puff::index::jointLog] [info] chunk size = 149,936,339
# [2021-01-14 14:35:29.051] [puff::index::jointLog] [info] chunk 0 = [0, 149,936,339)
# [2021-01-14 14:35:29.051] [puff::index::jointLog] [info] chunk 1 = [149,936,339, 299,872,647)
# [2021-01-14 14:35:59.282] [puff::index::jointLog] [info] finished populating pos vector
# [2021-01-14 14:35:59.282] [puff::index::jointLog] [info] writing index components
# [2021-01-14 14:35:59.957] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2021-01-14 14:36:00.050] [jLog] [info] done building index
#
# real	5m15.443s
# user	12m22.564s
# sys	0m7.639s

# %% [markdown]
# ## Mouse mm10

# %%
# %%bash
# time salmon index -i ../../reference/mouse-mm10/salmon \
#                   -t ../../reference/mouse-mm10/transcriptome.fa
# Out:
# Threads = 2
# Vertex length = 31
# Hash functions = 5
# Filter size = 2147483648
# Capacity = 2
# Files:
# ../../reference/mouse-mm10/salmon/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:2147483648
# Pass	Filling	Filtering
# 1	25	41
# 2	4	0
# True junctions count = 384058
# False junctions count = 762078
# Hash table size = 1146136
# Candidate marks count = 4180674
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 1
# True marks count: 2597976
# Edges construction time: 3
# --------------------------------------------------------------------------------
# Distinct junctions = 384058
#
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# Bitarray       535476928  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# Version Info: This is the most recent version of salmon.
# index ["../../reference/mouse-mm10/salmon"] did not previously exist  . . . creating it
# [2021-01-14 14:36:05.160] [jLog] [warning] The salmon index is being built without any decoy sequences.  It is recommended that decoy sequence (either computed auxiliary decoy sequence or the genome of the organism) be provided during indexing. Further details can be found at https://salmon.readthedocs.io/en/latest/salmon.html#preparing-transcriptome-indices-mapping-based-mode.
# [2021-01-14 14:36:05.160] [jLog] [info] building index
# out : ../../reference/mouse-mm10/salmon
# [2021-01-14 14:36:05.160] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179520], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179883], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000195858], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179932], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000180001], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000178815], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000177965], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000178909], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000177646], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000178230], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000178483], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179262], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000178549], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000193012], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179166], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179560], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000177839], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000103439], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000180266], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.495] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000103441], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.674] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000231713], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.674] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000231466], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.732] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000226589], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.752] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000228114], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.767] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000226226], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.808] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000196221], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.808] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179664], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.808] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000177564], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.809] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000103739], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.879] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000226961], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:06.972] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000227223], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:07.037] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000226615], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:07.236] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000226153], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:07.266] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000227002], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:07.295] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000226172], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:07.821] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000229312], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:08.540] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179793], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:09.154] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000178537], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:09.154] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000178862], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:36:10.269] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000165700], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2021-01-14 14:36:10.780] [puff::index::jointLog] [warning] Removed 734 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-14 14:36:10.780] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2021-01-14 14:36:10.780] [puff::index::jointLog] [info] Replaced 3 non-ATCG nucleotides
# [2021-01-14 14:36:10.780] [puff::index::jointLog] [info] Clipped poly-A tails from 619 transcripts
# wrote 110310 cleaned references
# [2021-01-14 14:36:11.266] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2021-01-14 14:36:12.781] [puff::index::jointLog] [info] ntHll estimated 101699889 distinct k-mers, setting filter size to 2^31
# allowedIn: 18
# Max Junction ID: 469291
# seen.size():3754337 kmerInfo.size():469292
# approximateContigTotalLength: 74214799
# counters for complex kmers:
# (prec>1 & succ>1)=16552 | (succ>1 & isStart)=299 | (prec>1 & isEnd)=297 | (isStart & isEnd)=31
# contig count: 578970 element count: 119564461 complex nodes: 17179
# # of ones in rank vector: 578969
# [2021-01-14 14:37:40.433] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2021-01-14 14:37:40.433] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory ../../reference/mouse-mm10/salmon
# size = 119564461
# -----------------------------------------
# | Loading contigs | Time = 10.737 ms
# -----------------------------------------
# size = 119564461
# -----------------------------------------
# | Loading contig boundaries | Time = 5.3704 ms
# -----------------------------------------
# Number of ones: 578969
# Number of ones per inventory item: 512
# Inventory entries filled: 1131
# 578969
# [2021-01-14 14:37:40.675] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2021-01-14 14:37:40.679] [puff::index::jointLog] [info] contig count for validation: 578,969
# [2021-01-14 14:37:40.847] [puff::index::jointLog] [info] Total # of Contigs : 578,969
# [2021-01-14 14:37:40.847] [puff::index::jointLog] [info] Total # of numerical Contigs : 578,969
# [2021-01-14 14:37:40.866] [puff::index::jointLog] [info] Total # of contig vec entries: 2,554,591
# [2021-01-14 14:37:40.866] [puff::index::jointLog] [info] bits per offset entry 22
# [2021-01-14 14:37:40.912] [puff::index::jointLog] [info] Done constructing the contig vector. 578970
# [2021-01-14 14:37:41.083] [puff::index::jointLog] [info] # segments = 578,969
# [2021-01-14 14:37:41.083] [puff::index::jointLog] [info] total length = 119,564,461
# [2021-01-14 14:37:41.118] [puff::index::jointLog] [info] Reading the reference files ...
# [2021-01-14 14:37:41.604] [puff::index::jointLog] [info] positional integer width = 27
# [2021-01-14 14:37:41.604] [puff::index::jointLog] [info] seqSize = 119,564,461
# [2021-01-14 14:37:41.604] [puff::index::jointLog] [info] rankSize = 119,564,461
# [2021-01-14 14:37:41.604] [puff::index::jointLog] [info] edgeVecSize = 0
# [2021-01-14 14:37:41.604] [puff::index::jointLog] [info] num keys = 102,195,391
# [Building BooPHF]  99.9 %   elapsed:   0 min 8  sec   remaining:   0 min 0  sec
# [2021-01-14 14:37:49.649] [puff::index::jointLog] [info] mphf size = 63.8338 MB
# [2021-01-14 14:37:49.745] [puff::index::jointLog] [info] chunk size = 59,782,231
# [2021-01-14 14:37:49.745] [puff::index::jointLog] [info] chunk 0 = [0, 59,782,231)
# [2021-01-14 14:37:49.745] [puff::index::jointLog] [info] chunk 1 = [59,782,231, 119,564,431)
# [2021-01-14 14:38:01.149] [puff::index::jointLog] [info] finished populating pos vector
# [2021-01-14 14:38:01.149] [puff::index::jointLog] [info] writing index components
# [2021-01-14 14:38:01.536] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2021-01-14 14:38:01.591] [jLog] [info] done building index
#
# real	2m1.501s
# user	4m38.065s
# sys	0m3.263s

# %% [markdown]
# ## Rat rnor6

# %%
# %%bash
# time salmon index -i ../../reference/rat-rnor6/salmon \
#                   -t ../../reference/rat-rnor6/transcriptome.fa
# Out:
# Threads = 2
# Vertex length = 31
# Hash functions = 5
# Filter size = 1073741824
# Capacity = 2
# Files:
# ../../reference/rat-rnor6/salmon/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:1073741824
# Pass	Filling	Filtering
# 1	10	20
# 2	1	0
# True junctions count = 89576
# False junctions count = 411257
# Hash table size = 500833
# Candidate marks count = 832925
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 357426
# Edges construction time: 2
# --------------------------------------------------------------------------------
# Distinct junctions = 89576
#
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# Bitarray       284664512  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# Version Info: This is the most recent version of salmon.
# index ["../../reference/rat-rnor6/salmon"] did not previously exist  . . . creating it
# [2021-01-14 14:38:06.658] [jLog] [warning] The salmon index is being built without any decoy sequences.  It is recommended that decoy sequence (either computed auxiliary decoy sequence or the genome of the organism) be provided during indexing. Further details can be found at https://salmon.readthedocs.io/en/latest/salmon.html#preparing-transcriptome-indices-mapping-based-mode.
# [2021-01-14 14:38:06.658] [jLog] [info] building index
# out : ../../reference/rat-rnor6/salmon
# [2021-01-14 14:38:06.658] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-01-14 14:38:06.745] [puff::index::jointLog] [warning] Entry with header [ENSRNOT00000070100], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:38:07.436] [puff::index::jointLog] [warning] Entry with header [ENSRNOT00000093397], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:38:07.597] [puff::index::jointLog] [warning] Entry with header [ENSRNOT00000069362], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:38:07.772] [puff::index::jointLog] [warning] Entry with header [ENSRNOT00000069393], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:38:08.147] [puff::index::jointLog] [warning] Entry with header [ENSRNOT00000085980], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2021-01-14 14:38:08.946] [puff::index::jointLog] [warning] Removed 641 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-14 14:38:08.946] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2021-01-14 14:38:08.947] [puff::index::jointLog] [info] Replaced 4,475,851 non-ATCG nucleotides
# [2021-01-14 14:38:08.947] [puff::index::jointLog] [info] Clipped poly-A tails from 0 transcripts
# wrote 40432 cleaned references
# [2021-01-14 14:38:09.110] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2021-01-14 14:38:09.647] [puff::index::jointLog] [info] ntHll estimated 54513812 distinct k-mers, setting filter size to 2^30
# allowedIn: 18
# Max Junction ID: 152375
# seen.size():1219009 kmerInfo.size():152376
# approximateContigTotalLength: 49096347
# counters for complex kmers:
# (prec>1 & succ>1)=2072 | (succ>1 & isStart)=55 | (prec>1 & isEnd)=45 | (isStart & isEnd)=2
# contig count: 161132 element count: 59161492 complex nodes: 2174
# # of ones in rank vector: 161131
# [2021-01-14 14:38:47.137] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2021-01-14 14:38:47.137] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory ../../reference/rat-rnor6/salmon
# size = 59161492
# -----------------------------------------
# | Loading contigs | Time = 5.4059 ms
# -----------------------------------------
# size = 59161492
# -----------------------------------------
# | Loading contig boundaries | Time = 2.8208 ms
# -----------------------------------------
# Number of ones: 161131
# Number of ones per inventory item: 512
# Inventory entries filled: 315
# 161131
# [2021-01-14 14:38:47.252] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2021-01-14 14:38:47.253] [puff::index::jointLog] [info] contig count for validation: 161,131
# [2021-01-14 14:38:47.284] [puff::index::jointLog] [info] Total # of Contigs : 161,131
# [2021-01-14 14:38:47.284] [puff::index::jointLog] [info] Total # of numerical Contigs : 161,131
# [2021-01-14 14:38:47.286] [puff::index::jointLog] [info] Total # of contig vec entries: 323,442
# [2021-01-14 14:38:47.286] [puff::index::jointLog] [info] bits per offset entry 19
# [2021-01-14 14:38:47.292] [puff::index::jointLog] [info] Done constructing the contig vector. 161132
# [2021-01-14 14:38:47.318] [puff::index::jointLog] [info] # segments = 161,131
# [2021-01-14 14:38:47.318] [puff::index::jointLog] [info] total length = 59,161,492
# [2021-01-14 14:38:47.330] [puff::index::jointLog] [info] Reading the reference files ...
# [2021-01-14 14:38:47.516] [puff::index::jointLog] [info] positional integer width = 26
# [2021-01-14 14:38:47.516] [puff::index::jointLog] [info] seqSize = 59,161,492
# [2021-01-14 14:38:47.516] [puff::index::jointLog] [info] rankSize = 59,161,492
# [2021-01-14 14:38:47.516] [puff::index::jointLog] [info] edgeVecSize = 0
# [2021-01-14 14:38:47.516] [puff::index::jointLog] [info] num keys = 54,327,562
# [Building BooPHF]  100  %   elapsed:   0 min 4  sec   remaining:   0 min 0  sec
# [2021-01-14 14:38:51.902] [puff::index::jointLog] [info] mphf size = 33.9347 MB
# [2021-01-14 14:38:51.955] [puff::index::jointLog] [info] chunk size = 29,580,746
# [2021-01-14 14:38:51.955] [puff::index::jointLog] [info] chunk 0 = [0, 29,580,762)
# [2021-01-14 14:38:51.955] [puff::index::jointLog] [info] chunk 1 = [29,580,762, 59,161,462)
# [2021-01-14 14:38:58.325] [puff::index::jointLog] [info] finished populating pos vector
# [2021-01-14 14:38:58.325] [puff::index::jointLog] [info] writing index components
# [2021-01-14 14:38:58.540] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2021-01-14 14:38:58.561] [jLog] [info] done building index
#
# real	0m56.936s
# user	2m4.443s
# sys	0m1.479s

# %% [markdown]
# ## Zebrafish dr82

# %%
# %%bash
# time salmon index -i ../../reference/zebrafish-dr82/salmon \
#                   -t ../../reference/zebrafish-dr82/transcriptome.fa
# Out:
# Threads = 2
# Vertex length = 31
# Hash functions = 5
# Filter size = 2147483648
# Capacity = 2
# Files:
# ../../reference/zebrafish-dr82/salmon/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:2147483648
# Pass	Filling	Filtering
# 1	15	25
# 2	2	0
# True junctions count = 195042
# False junctions count = 361019
# Hash table size = 556061
# Candidate marks count = 2174715
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 1509903
# Edges construction time: 2
# --------------------------------------------------------------------------------
# Distinct junctions = 195042
#
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# Bitarray       359708800  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# Version Info: This is the most recent version of salmon.
# index ["../../reference/zebrafish-dr82/salmon"] did not previously exist  . . . creating it
# [2021-01-14 14:39:03.622] [jLog] [warning] The salmon index is being built without any decoy sequences.  It is recommended that decoy sequence (either computed auxiliary decoy sequence or the genome of the organism) be provided during indexing. Further details can be found at https://salmon.readthedocs.io/en/latest/salmon.html#preparing-transcriptome-indices-mapping-based-mode.
# [2021-01-14 14:39:03.622] [jLog] [info] building index
# out : ../../reference/zebrafish-dr82/salmon
# [2021-01-14 14:39:03.622] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-01-14 14:39:05.300] [puff::index::jointLog] [warning] Entry with header [ENSDART00000171117], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:39:05.300] [puff::index::jointLog] [warning] Entry with header [ENSDART00000162914], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:39:06.028] [puff::index::jointLog] [warning] Entry with header [ENSDART00000151250], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:39:06.028] [puff::index::jointLog] [warning] Entry with header [ENSDART00000151491], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:39:06.028] [puff::index::jointLog] [warning] Entry with header [ENSDART00000150889], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:39:06.028] [puff::index::jointLog] [warning] Entry with header [ENSDART00000151572], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:39:06.028] [puff::index::jointLog] [warning] Entry with header [ENSDART00000151686], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:39:06.028] [puff::index::jointLog] [warning] Entry with header [ENSDART00000151215], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:39:06.028] [puff::index::jointLog] [warning] Entry with header [ENSDART00000151691], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2021-01-14 14:39:06.901] [puff::index::jointLog] [warning] Removed 1024 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-14 14:39:06.901] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2021-01-14 14:39:06.901] [puff::index::jointLog] [info] Replaced 9,656,118 non-ATCG nucleotides
# [2021-01-14 14:39:06.901] [puff::index::jointLog] [info] Clipped poly-A tails from 2 transcripts
# wrote 56336 cleaned references
# [2021-01-14 14:39:07.146] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2021-01-14 14:39:07.950] [puff::index::jointLog] [info] ntHll estimated 69059184 distinct k-mers, setting filter size to 2^31
# allowedIn: 18
# Max Junction ID: 262541
# seen.size():2100337 kmerInfo.size():262542
# approximateContigTotalLength: 57174026
# counters for complex kmers:
# (prec>1 & succ>1)=4698 | (succ>1 & isStart)=136 | (prec>1 & isEnd)=129 | (isStart & isEnd)=6
# contig count: 315152 element count: 78104376 complex nodes: 4969
# # of ones in rank vector: 315151
# [2021-01-14 14:39:59.485] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2021-01-14 14:39:59.485] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory ../../reference/zebrafish-dr82/salmon
# size = 78104376
# -----------------------------------------
# | Loading contigs | Time = 7.6784 ms
# -----------------------------------------
# size = 78104376
# -----------------------------------------
# | Loading contig boundaries | Time = 4.4412 ms
# -----------------------------------------
# Number of ones: 315151
# Number of ones per inventory item: 512
# Inventory entries filled: 616
# 315151
# [2021-01-14 14:39:59.652] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2021-01-14 14:39:59.655] [puff::index::jointLog] [info] contig count for validation: 315,151
# [2021-01-14 14:39:59.749] [puff::index::jointLog] [info] Total # of Contigs : 315,151
# [2021-01-14 14:39:59.749] [puff::index::jointLog] [info] Total # of numerical Contigs : 315,151
# [2021-01-14 14:39:59.757] [puff::index::jointLog] [info] Total # of contig vec entries: 1,472,306
# [2021-01-14 14:39:59.757] [puff::index::jointLog] [info] bits per offset entry 21
# [2021-01-14 14:39:59.776] [puff::index::jointLog] [info] Done constructing the contig vector. 315152
# [2021-01-14 14:39:59.876] [puff::index::jointLog] [info] # segments = 315,151
# [2021-01-14 14:39:59.876] [puff::index::jointLog] [info] total length = 78,104,376
# [2021-01-14 14:39:59.893] [puff::index::jointLog] [info] Reading the reference files ...
# [2021-01-14 14:40:00.155] [puff::index::jointLog] [info] positional integer width = 27
# [2021-01-14 14:40:00.155] [puff::index::jointLog] [info] seqSize = 78,104,376
# [2021-01-14 14:40:00.155] [puff::index::jointLog] [info] rankSize = 78,104,376
# [2021-01-14 14:40:00.155] [puff::index::jointLog] [info] edgeVecSize = 0
# [2021-01-14 14:40:00.155] [puff::index::jointLog] [info] num keys = 68,649,846
# [Building BooPHF]  100  %   elapsed:   0 min 5  sec   remaining:   0 min 0  sec
# [2021-01-14 14:40:05.119] [puff::index::jointLog] [info] mphf size = 42.8806 MB
# [2021-01-14 14:40:05.187] [puff::index::jointLog] [info] chunk size = 39,052,188
# [2021-01-14 14:40:05.187] [puff::index::jointLog] [info] chunk 0 = [0, 39,052,188)
# [2021-01-14 14:40:05.187] [puff::index::jointLog] [info] chunk 1 = [39,052,188, 78,104,346)
# [2021-01-14 14:40:13.050] [puff::index::jointLog] [info] finished populating pos vector
# [2021-01-14 14:40:13.050] [puff::index::jointLog] [info] writing index components
# [2021-01-14 14:40:13.286] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2021-01-14 14:40:13.307] [jLog] [info] done building index
#
# real	1m14.717s
# user	2m45.002s
# sys	0m1.847s

# %% [markdown]
# ## Arabidopsis tair10

# %%
# %%bash
# time salmon index -i ../../reference/arabidopsis-tair10/salmon \
#                   -t ../../reference/arabidopsis-tair10/transcriptome.fa
# Out:
# Threads = 2
# Vertex length = 31
# Hash functions = 5
# Filter size = 1073741824
# Capacity = 2
# Files:
# ../../reference/arabidopsis-tair10/salmon/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:1073741824
# Pass	Filling	Filtering
# 1	11	17
# 2	2	0
# True junctions count = 171142
# False junctions count = 305748
# Hash table size = 476890
# Candidate marks count = 1153119
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 744479
# Edges construction time: 2
# --------------------------------------------------------------------------------
# Distinct junctions = 171142
#
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# Bitarray       250257984  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# Version Info: This is the most recent version of salmon.
# index ["../../reference/arabidopsis-tair10/salmon"] did not previously exist  . . . creating it
# [2021-01-14 14:40:18.365] [jLog] [warning] The salmon index is being built without any decoy sequences.  It is recommended that decoy sequence (either computed auxiliary decoy sequence or the genome of the organism) be provided during indexing. Further details can be found at https://salmon.readthedocs.io/en/latest/salmon.html#preparing-transcriptome-indices-mapping-based-mode.
# [2021-01-14 14:40:18.365] [jLog] [info] building index
# out : ../../reference/arabidopsis-tair10/salmon
# [2021-01-14 14:40:18.365] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-01-14 14:40:20.175] [puff::index::jointLog] [warning] Entry with header [ATMG00665.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2021-01-14 14:40:20.179] [puff::index::jointLog] [warning] Removed 585 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-14 14:40:20.179] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2021-01-14 14:40:20.179] [puff::index::jointLog] [info] Replaced 697 non-ATCG nucleotides
# [2021-01-14 14:40:20.179] [puff::index::jointLog] [info] Clipped poly-A tails from 24 transcripts
# wrote 41085 cleaned references
# [2021-01-14 14:40:20.319] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2021-01-14 14:40:20.807] [puff::index::jointLog] [info] ntHll estimated 47932913 distinct k-mers, setting filter size to 2^30
# allowedIn: 12
# Max Junction ID: 227382
# seen.size():1819065 kmerInfo.size():227383
# approximateContigTotalLength: 38793320
# counters for complex kmers:
# (prec>1 & succ>1)=7875 | (succ>1 & isStart)=85 | (prec>1 & isEnd)=64 | (isStart & isEnd)=16
# contig count: 282612 element count: 56239318 complex nodes: 8040
# # of ones in rank vector: 282611
# [2021-01-14 14:40:57.808] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2021-01-14 14:40:57.808] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory ../../reference/arabidopsis-tair10/salmon
# size = 56239318
# -----------------------------------------
# | Loading contigs | Time = 5.9494 ms
# -----------------------------------------
# size = 56239318
# -----------------------------------------
# | Loading contig boundaries | Time = 2.8906 ms
# -----------------------------------------
# Number of ones: 282611
# Number of ones per inventory item: 512
# Inventory entries filled: 552
# 282611
# [2021-01-14 14:40:57.947] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2021-01-14 14:40:57.950] [puff::index::jointLog] [info] contig count for validation: 282,611
# [2021-01-14 14:40:58.009] [puff::index::jointLog] [info] Total # of Contigs : 282,611
# [2021-01-14 14:40:58.009] [puff::index::jointLog] [info] Total # of numerical Contigs : 282,611
# [2021-01-14 14:40:58.014] [puff::index::jointLog] [info] Total # of contig vec entries: 727,451
# [2021-01-14 14:40:58.014] [puff::index::jointLog] [info] bits per offset entry 20
# [2021-01-14 14:40:58.025] [puff::index::jointLog] [info] Done constructing the contig vector. 282612
# [2021-01-14 14:40:58.084] [puff::index::jointLog] [info] # segments = 282,611
# [2021-01-14 14:40:58.084] [puff::index::jointLog] [info] total length = 56,239,318
# [2021-01-14 14:40:58.096] [puff::index::jointLog] [info] Reading the reference files ...
# [2021-01-14 14:40:58.282] [puff::index::jointLog] [info] positional integer width = 26
# [2021-01-14 14:40:58.282] [puff::index::jointLog] [info] seqSize = 56,239,318
# [2021-01-14 14:40:58.282] [puff::index::jointLog] [info] rankSize = 56,239,318
# [2021-01-14 14:40:58.282] [puff::index::jointLog] [info] edgeVecSize = 0
# [2021-01-14 14:40:58.282] [puff::index::jointLog] [info] num keys = 47,760,988
# [Building BooPHF]  100  %   elapsed:   0 min 4  sec   remaining:   0 min 0  sec
# [2021-01-14 14:41:02.091] [puff::index::jointLog] [info] mphf size = 29.8331 MB
# [2021-01-14 14:41:02.141] [puff::index::jointLog] [info] chunk size = 28,119,659
# [2021-01-14 14:41:02.141] [puff::index::jointLog] [info] chunk 0 = [0, 28,119,659)
# [2021-01-14 14:41:02.141] [puff::index::jointLog] [info] chunk 1 = [28,119,659, 56,239,288)
# [2021-01-14 14:41:06.717] [puff::index::jointLog] [info] finished populating pos vector
# [2021-01-14 14:41:06.717] [puff::index::jointLog] [info] writing index components
# [2021-01-14 14:41:06.909] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2021-01-14 14:41:06.926] [jLog] [info] done building index
#
# real	0m53.594s
# user	1m56.533s
# sys	0m1.471s

# %% [markdown]
# ## Fly dm6

# %%
# %%bash
# time salmon index -i ../../reference/fly-dm6/salmon \
#                   -t ../../reference/fly-dm6/transcriptome.fa
# Out:
# Threads = 2
# Vertex length = 31
# Hash functions = 5
# Filter size = 1073741824
# Capacity = 2
# Files:
# ../../reference/fly-dm6/salmon/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:1073741824
# Pass	Filling	Filtering
# 1	12	16
# 2	1	0
# True junctions count = 53037
# False junctions count = 67872
# Hash table size = 120909
# Candidate marks count = 446198
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 312196
# Edges construction time: 2
# --------------------------------------------------------------------------------
# Distinct junctions = 53037
#
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# Bitarray       184004288  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# Version Info: This is the most recent version of salmon.
# index ["../../reference/fly-dm6/salmon"] did not previously exist  . . . creating it
# [2021-01-14 14:41:11.988] [jLog] [warning] The salmon index is being built without any decoy sequences.  It is recommended that decoy sequence (either computed auxiliary decoy sequence or the genome of the organism) be provided during indexing. Further details can be found at https://salmon.readthedocs.io/en/latest/salmon.html#preparing-transcriptome-indices-mapping-based-mode.
# [2021-01-14 14:41:11.988] [jLog] [info] building index
# out : ../../reference/fly-dm6/salmon
# [2021-01-14 14:41:11.988] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-01-14 14:41:12.623] [puff::index::jointLog] [warning] Entry with header [FBtr0091693], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:41:14.355] [puff::index::jointLog] [warning] Entry with header [FBtr0346890], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:41:14.356] [puff::index::jointLog] [warning] Entry with header [FBtr0346894], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:41:14.356] [puff::index::jointLog] [warning] Entry with header [FBtr0346898], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:41:14.393] [puff::index::jointLog] [warning] Entry with header [FBtr0346870], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:41:14.393] [puff::index::jointLog] [warning] Entry with header [FBtr0346875], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:41:14.394] [puff::index::jointLog] [warning] Entry with header [FBtr0346880], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-14 14:41:14.394] [puff::index::jointLog] [warning] Entry with header [FBtr0346884], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2021-01-14 14:41:14.394] [puff::index::jointLog] [warning] Removed 1100 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-14 14:41:14.394] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2021-01-14 14:41:14.394] [puff::index::jointLog] [info] Replaced 0 non-ATCG nucleotides
# [2021-01-14 14:41:14.394] [puff::index::jointLog] [info] Clipped poly-A tails from 9 transcripts
# wrote 33406 cleaned references
# [2021-01-14 14:41:14.560] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2021-01-14 14:41:15.396] [puff::index::jointLog] [info] ntHll estimated 34910373 distinct k-mers, setting filter size to 2^30
# allowedIn: 11
# Max Junction ID: 77320
# seen.size():618569 kmerInfo.size():77321
# approximateContigTotalLength: 29995946
# counters for complex kmers:
# (prec>1 & succ>1)=851 | (succ>1 & isStart)=19 | (prec>1 & isEnd)=18 | (isStart & isEnd)=7
# contig count: 78909 element count: 37483673 complex nodes: 895
# # of ones in rank vector: 78908
# [2021-01-14 14:41:51.298] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2021-01-14 14:41:51.298] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory ../../reference/fly-dm6/salmon
# size = 37483673
# -----------------------------------------
# | Loading contigs | Time = 3.4136 ms
# -----------------------------------------
# size = 37483673
# -----------------------------------------
# | Loading contig boundaries | Time = 2.1103 ms
# -----------------------------------------
# Number of ones: 78908
# Number of ones per inventory item: 512
# Inventory entries filled: 155
# 78908
# [2021-01-14 14:41:51.376] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2021-01-14 14:41:51.377] [puff::index::jointLog] [info] contig count for validation: 78,908
# [2021-01-14 14:41:51.405] [puff::index::jointLog] [info] Total # of Contigs : 78,908
# [2021-01-14 14:41:51.405] [puff::index::jointLog] [info] Total # of numerical Contigs : 78,908
# [2021-01-14 14:41:51.407] [puff::index::jointLog] [info] Total # of contig vec entries: 284,696
# [2021-01-14 14:41:51.407] [puff::index::jointLog] [info] bits per offset entry 19
# [2021-01-14 14:41:51.410] [puff::index::jointLog] [info] Done constructing the contig vector. 78909
# [2021-01-14 14:41:51.432] [puff::index::jointLog] [info] # segments = 78,908
# [2021-01-14 14:41:51.432] [puff::index::jointLog] [info] total length = 37,483,673
# [2021-01-14 14:41:51.443] [puff::index::jointLog] [info] Reading the reference files ...
# [2021-01-14 14:41:51.664] [puff::index::jointLog] [info] positional integer width = 26
# [2021-01-14 14:41:51.664] [puff::index::jointLog] [info] seqSize = 37,483,673
# [2021-01-14 14:41:51.664] [puff::index::jointLog] [info] rankSize = 37,483,673
# [2021-01-14 14:41:51.664] [puff::index::jointLog] [info] edgeVecSize = 0
# [2021-01-14 14:41:51.664] [puff::index::jointLog] [info] num keys = 35,116,433
# [Building BooPHF]  100  %   elapsed:   0 min 3  sec   remaining:   0 min 0  sec
# [2021-01-14 14:41:54.992] [puff::index::jointLog] [info] mphf size = 21.935 MB
# [2021-01-14 14:41:55.026] [puff::index::jointLog] [info] chunk size = 18,741,837
# [2021-01-14 14:41:55.026] [puff::index::jointLog] [info] chunk 0 = [0, 18,741,837)
# [2021-01-14 14:41:55.026] [puff::index::jointLog] [info] chunk 1 = [18,741,837, 37,483,643)
# [2021-01-14 14:41:58.714] [puff::index::jointLog] [info] finished populating pos vector
# [2021-01-14 14:41:58.714] [puff::index::jointLog] [info] writing index components
# [2021-01-14 14:41:58.856] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2021-01-14 14:41:58.878] [jLog] [info] done building index
#
# real	0m51.922s
# user	1m53.165s
# sys	0m1.231s

# %% [markdown]
# ## Worm ws260

# %%
# %%bash
# time salmon index -i ../../reference/worm-ws260/salmon \
#                   -t ../../reference/worm-ws260/transcriptome.fa
# Out:
# Threads = 2
# Vertex length = 31
# Hash functions = 5
# Filter size = 536870912
# Capacity = 2
# Files:
# ../../reference/worm-ws260/salmon/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:536870912
# Pass	Filling	Filtering
# 1	7	12
# 2	1	0
# True junctions count = 47878
# False junctions count = 275510
# Hash table size = 323388
# Candidate marks count = 691481
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 227173
# Edges construction time: 1
# --------------------------------------------------------------------------------
# Distinct junctions = 47878
#
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# Bitarray       150057344  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# Version Info: This is the most recent version of salmon.
# index ["../../reference/worm-ws260/salmon"] did not previously exist  . . . creating it
# [2021-01-14 14:42:03.945] [jLog] [warning] The salmon index is being built without any decoy sequences.  It is recommended that decoy sequence (either computed auxiliary decoy sequence or the genome of the organism) be provided during indexing. Further details can be found at https://salmon.readthedocs.io/en/latest/salmon.html#preparing-transcriptome-indices-mapping-based-mode.
# [2021-01-14 14:42:03.945] [jLog] [info] building index
# out : ../../reference/worm-ws260/salmon
# [2021-01-14 14:42:03.945] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-01-14 14:42:05.015] [puff::index::jointLog] [warning] Entry with header [W03F8.6d], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2021-01-14 14:42:05.705] [puff::index::jointLog] [warning] Removed 366 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-14 14:42:05.705] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2021-01-14 14:42:05.706] [puff::index::jointLog] [info] Replaced 0 non-ATCG nucleotides
# [2021-01-14 14:42:05.706] [puff::index::jointLog] [info] Clipped poly-A tails from 20 transcripts
# wrote 33668 cleaned references
# [2021-01-14 14:42:05.830] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2021-01-14 14:42:06.270] [puff::index::jointLog] [info] ntHll estimated 28361318 distinct k-mers, setting filter size to 2^29
# allowedIn: 14
# Max Junction ID: 82677
# seen.size():661425 kmerInfo.size():82678
# approximateContigTotalLength: 24664453
# counters for complex kmers:
# (prec>1 & succ>1)=523 | (succ>1 & isStart)=17 | (prec>1 & isEnd)=22 | (isStart & isEnd)=17
# contig count: 78083 element count: 30980043 complex nodes: 579
# # of ones in rank vector: 78082
# [2021-01-14 14:42:31.143] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2021-01-14 14:42:31.143] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory ../../reference/worm-ws260/salmon
# size = 30980043
# -----------------------------------------
# | Loading contigs | Time = 2.835 ms
# -----------------------------------------
# size = 30980043
# -----------------------------------------
# | Loading contig boundaries | Time = 698.65 us
# -----------------------------------------
# Number of ones: 78082
# Number of ones per inventory item: 512
# Inventory entries filled: 153
# 78082
# [2021-01-14 14:42:31.206] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2021-01-14 14:42:31.206] [puff::index::jointLog] [info] contig count for validation: 78,082
# [2021-01-14 14:42:31.230] [puff::index::jointLog] [info] Total # of Contigs : 78,082
# [2021-01-14 14:42:31.230] [puff::index::jointLog] [info] Total # of numerical Contigs : 78,082
# [2021-01-14 14:42:31.231] [puff::index::jointLog] [info] Total # of contig vec entries: 195,478
# [2021-01-14 14:42:31.231] [puff::index::jointLog] [info] bits per offset entry 18
# [2021-01-14 14:42:31.233] [puff::index::jointLog] [info] Done constructing the contig vector. 78083
# [2021-01-14 14:42:31.250] [puff::index::jointLog] [info] # segments = 78,082
# [2021-01-14 14:42:31.250] [puff::index::jointLog] [info] total length = 30,980,043
# [2021-01-14 14:42:31.259] [puff::index::jointLog] [info] Reading the reference files ...
# [2021-01-14 14:42:31.406] [puff::index::jointLog] [info] positional integer width = 25
# [2021-01-14 14:42:31.406] [puff::index::jointLog] [info] seqSize = 30,980,043
# [2021-01-14 14:42:31.406] [puff::index::jointLog] [info] rankSize = 30,980,043
# [2021-01-14 14:42:31.406] [puff::index::jointLog] [info] edgeVecSize = 0
# [2021-01-14 14:42:31.406] [puff::index::jointLog] [info] num keys = 28,637,583
# [Building BooPHF]  100  %   elapsed:   0 min 3  sec   remaining:   0 min 0  sec
# [2021-01-14 14:42:34.105] [puff::index::jointLog] [info] mphf size = 17.8882 MB
# [2021-01-14 14:42:34.132] [puff::index::jointLog] [info] chunk size = 15,490,022
# [2021-01-14 14:42:34.132] [puff::index::jointLog] [info] chunk 0 = [0, 15,490,022)
# [2021-01-14 14:42:34.132] [puff::index::jointLog] [info] chunk 1 = [15,490,022, 30,980,013)
# [2021-01-14 14:42:37.125] [puff::index::jointLog] [info] finished populating pos vector
# [2021-01-14 14:42:37.125] [puff::index::jointLog] [info] writing index components
# [2021-01-14 14:42:37.243] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2021-01-14 14:42:37.258] [jLog] [info] done building index
#
# real	0m38.345s
# user	1m19.895s
# sys	0m1.051s
