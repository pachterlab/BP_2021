# %%
# !date
# Out:
# Thu Jan 14 14:19:40 PST 2021

# %% [markdown]
# # Salmon index

# %% [markdown]
# ## Human GRCh38

# %%
# !../scripts/mkref_salmon.sh \
-o ../../reference/human-grch38/salmon \
-g ../../reference/human-grch38/genome.fa \
-a ../../reference/human-grch38/genes.gtf \
-t ../../reference/human-grch38/transcriptome.fa \
-m ../../reference/human-grch38/t2g.txt
# Out:
# [bash] making gentrome and decoys
# [salmon] building decoy index
# Version Info: This is the most recent version of salmon.
# index ["../../reference/human-grch38/salmon/salmon_index"] did not previously exist  . . . creating it
# [2021-01-19 10:56:52.001] [jLog] [info] building index
# out : ../../reference/human-grch38/salmon/salmon_index
# [2021-01-19 10:56:52.002] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-01-19 10:56:54.283] [puff::index::jointLog] [warning] Entry with header [ENST00000415118], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.283] [puff::index::jointLog] [warning] Entry with header [ENST00000434970], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.283] [puff::index::jointLog] [warning] Entry with header [ENST00000448914], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000439842], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000390567], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000452198], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000390569], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000437320], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000390571], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000390572], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000450276], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000390574], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000390575], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000431870], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000390578], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000451044], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000390580], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000390581], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000431440], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000390583], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000390584], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000390585], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000430425], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000454691], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000390588], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000414852], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000390590], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.509] [puff::index::jointLog] [warning] Entry with header [ENST00000390591], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.510] [puff::index::jointLog] [warning] Entry with header [ENST00000454908], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.510] [puff::index::jointLog] [warning] Entry with header [ENST00000518246], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.511] [puff::index::jointLog] [warning] Entry with header [ENST00000604642], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.511] [puff::index::jointLog] [warning] Entry with header [ENST00000603326], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.511] [puff::index::jointLog] [warning] Entry with header [ENST00000604950], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.511] [puff::index::jointLog] [warning] Entry with header [ENST00000603077], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.511] [puff::index::jointLog] [warning] Entry with header [ENST00000605284], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.512] [puff::index::jointLog] [warning] Entry with header [ENST00000604446], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.512] [puff::index::jointLog] [warning] Entry with header [ENST00000603693], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.512] [puff::index::jointLog] [warning] Entry with header [ENST00000603935], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.512] [puff::index::jointLog] [warning] Entry with header [ENST00000604102], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:54.512] [puff::index::jointLog] [warning] Entry with header [ENST00000604838], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 10:56:59.196] [puff::index::jointLog] [warning] Entry with header [ENST00000632684], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2021-01-19 10:57:50.149] [puff::index::jointLog] [warning] Removed 321 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-19 10:57:50.149] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2021-01-19 10:57:50.149] [puff::index::jointLog] [info] Replaced 153,901,651 non-ATCG nucleotides
# [2021-01-19 10:57:50.149] [puff::index::jointLog] [info] Clipped poly-A tails from 1,426 transcripts
# wrote 172751 cleaned references
# [2021-01-19 10:57:53.769] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2021-01-19 10:58:21.336] [puff::index::jointLog] [info] ntHll estimated 2629899985 distinct k-mers, setting filter size to 2^36
# Threads = 10
# Vertex length = 31
# Hash functions = 5
# Filter size = 68719476736
# Capacity = 2
# Files:
# ../../reference/human-grch38/salmon/salmon_index/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:68719476736
# Pass	Filling	Filtering
# 1	143	243
# 2	54	8
# True junctions count = 22125013
# False junctions count = 3714273
# Hash table size = 25839286
# Candidate marks count = 358123717
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 11
# True marks count: 353865533
# Edges construction time: 73
# --------------------------------------------------------------------------------
# Distinct junctions = 22125013
#
# allowedIn: 15
# Max Junction ID: 22127502
# seen.size():177020025 kmerInfo.size():22127503
# approximateContigTotalLength: 1341223878
# counters for complex kmers:
# (prec>1 & succ>1)=5265518 | (succ>1 & isStart)=1089 | (prec>1 & isEnd)=1145 | (isStart & isEnd)=75
# contig count: 37010079 element count: 3774199677 complex nodes: 5267827
# # of ones in rank vector: 37010078
# [2021-01-19 11:14:42.958] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2021-01-19 11:14:42.958] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory ../../reference/human-grch38/salmon/salmon_index
# size = 3774199677
# -----------------------------------------
# | Loading contigs | Time = 318.63 ms
# -----------------------------------------
# size = 3774199677
# -----------------------------------------
# | Loading contig boundaries | Time = 157.77 ms
# -----------------------------------------
# Number of ones: 37010078
# Number of ones per inventory item: 512
# Inventory entries filled: 72286
# 37010078
# [2021-01-19 11:14:50.928] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2021-01-19 11:14:51.455] [puff::index::jointLog] [info] contig count for validation: 37,010,078
# [2021-01-19 11:15:09.785] [puff::index::jointLog] [info] Total # of Contigs : 37,010,078
# [2021-01-19 11:15:09.785] [puff::index::jointLog] [info] Total # of numerical Contigs : 37,010,078
# [2021-01-19 11:15:11.665] [puff::index::jointLog] [info] Total # of contig vec entries: 367,418,806
# [2021-01-19 11:15:11.665] [puff::index::jointLog] [info] bits per offset entry 29
# [2021-01-19 11:15:20.327] [puff::index::jointLog] [info] Done constructing the contig vector. 37010079
# [2021-01-19 11:15:42.830] [puff::index::jointLog] [info] # segments = 37,010,078
# [2021-01-19 11:15:42.830] [puff::index::jointLog] [info] total length = 3,774,199,677
# [2021-01-19 11:15:43.067] [puff::index::jointLog] [info] Reading the reference files ...
# [2021-01-19 11:15:53.878] [puff::index::jointLog] [info] positional integer width = 32
# [2021-01-19 11:15:53.878] [puff::index::jointLog] [info] seqSize = 3,774,199,677
# [2021-01-19 11:15:53.878] [puff::index::jointLog] [info] rankSize = 3,774,199,677
# [2021-01-19 11:15:53.878] [puff::index::jointLog] [info] edgeVecSize = 0
# [2021-01-19 11:15:53.878] [puff::index::jointLog] [info] num keys = 2,663,897,337
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# [Building BooPHF]  99.7 %   elapsed:   1 min 22 sec   remaining:   0 min 0  sec
# Bitarray     13957971968  bits (99.99 %)   (array + ranks )
# final hash        720384  bits (0.01 %) (nb in final hash 2144)
# [2021-01-19 11:17:16.516] [puff::index::jointLog] [info] mphf size = 1664.01 MB
# [2021-01-19 11:17:19.096] [puff::index::jointLog] [info] chunk size = 377,419,968
# [2021-01-19 11:17:19.096] [puff::index::jointLog] [info] chunk 0 = [0, 377,419,968)
# [2021-01-19 11:17:19.096] [puff::index::jointLog] [info] chunk 1 = [377,419,968, 754,839,936)
# [2021-01-19 11:17:19.096] [puff::index::jointLog] [info] chunk 2 = [754,839,936, 1,132,259,904)
# [2021-01-19 11:17:19.096] [puff::index::jointLog] [info] chunk 3 = [1,132,259,904, 1,509,679,872)
# [2021-01-19 11:17:19.096] [puff::index::jointLog] [info] chunk 4 = [1,509,679,872, 1,887,099,867)
# [2021-01-19 11:17:19.096] [puff::index::jointLog] [info] chunk 5 = [1,887,099,867, 2,264,519,835)
# [2021-01-19 11:17:19.096] [puff::index::jointLog] [info] chunk 6 = [2,264,519,835, 2,641,939,803)
# [2021-01-19 11:17:19.096] [puff::index::jointLog] [info] chunk 7 = [2,641,939,803, 3,019,359,771)
# [2021-01-19 11:17:19.096] [puff::index::jointLog] [info] chunk 8 = [3,019,359,771, 3,396,779,739)
# [2021-01-19 11:17:19.096] [puff::index::jointLog] [info] chunk 9 = [3,396,779,739, 3,774,199,647)
# [2021-01-19 11:19:18.902] [puff::index::jointLog] [info] finished populating pos vector
# [2021-01-19 11:19:18.902] [puff::index::jointLog] [info] writing index components
# [2021-01-19 11:19:28.932] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2021-01-19 11:19:29.541] [jLog] [info] done building index
# [bash] making decoy t2g

# %% [markdown]
# ## Human-mouse hg19-mm10

# %%
# !../scripts/mkref_salmon.sh \
-o ../../reference/human_mouse-hg19_mm10/salmon \
-g ../../reference/human_mouse-hg19_mm10/genome.fa \
-a ../../reference/human_mouse-hg19_mm10/genes.gtf \
-t ../../reference/human_mouse-hg19_mm10/transcriptome.fa \
-m ../../reference/human_mouse-hg19_mm10/t2g.txt
# Out:
# [bash] making gentrome and decoys
# [salmon] building decoy index
# Version Info: This is the most recent version of salmon.
# index ["../../reference/human_mouse-hg19_mm10/salmon/salmon_index"] did not previously exist  . . . creating it
# [2021-01-19 12:10:12.335] [jLog] [info] building index
# out : ../../reference/human_mouse-hg19_mm10/salmon/salmon_index
# [2021-01-19 12:10:12.335] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-01-19 12:10:13.043] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000594394], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:13.379] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000606517], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:13.703] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000598940], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.293] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000598624], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.405] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000543745], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.569] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000415118], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.570] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000434970], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.570] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000448914], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000439842], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390567], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000452198], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390569], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000437320], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390571], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390572], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000450276], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390574], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390575], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000431870], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390578], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000451044], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390580], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390581], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000431440], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390583], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390584], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390585], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000430425], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000454691], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390588], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000414852], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390590], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000390591], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.899] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000454908], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.900] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000518246], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.901] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000604642], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.901] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000603326], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.901] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000604950], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.901] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000603077], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.901] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000605284], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.903] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000604446], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.903] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000603693], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.903] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000603935], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.903] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000604102], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:14.903] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000604838], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:15.413] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000602572], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:16.012] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000579054], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:17.166] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000595481], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:18.421] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000473810], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:18.524] [puff::index::jointLog] [warning] Entry with header [hg19_ENST00000603775], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:20.767] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000191703], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000179520], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000179883], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000195858], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000179932], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000180001], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178815], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000177965], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178909], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000177646], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178230], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178483], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000179262], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178549], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000193012], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000179166], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000179560], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178902], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000192089], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000177839], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000170385], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000103439], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000180266], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178811], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:21.918] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000103441], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:22.130] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000231713], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:22.130] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000231466], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:22.175] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000226589], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:22.196] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000228114], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:22.214] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000226226], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:22.262] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000196221], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:22.262] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000179664], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:22.262] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000177564], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:22.263] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000103739], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:22.343] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000226961], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:22.450] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000227223], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:22.520] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000226615], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:22.739] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000226153], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:22.772] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000227002], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:22.804] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000226172], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:23.340] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000229312], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:24.671] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000179793], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:24.989] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000200713], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:25.274] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178537], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:25.275] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000178862], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 12:10:26.205] [puff::index::jointLog] [warning] Entry with header [mm10_ENSMUST00000165700], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2021-01-19 12:12:26.131] [puff::index::jointLog] [warning] Removed 3127 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-19 12:12:26.131] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2021-01-19 12:12:26.136] [puff::index::jointLog] [info] Replaced 315,107,797 non-ATCG nucleotides
# [2021-01-19 12:12:26.136] [puff::index::jointLog] [info] Clipped poly-A tails from 2,163 transcripts
# wrote 330072 cleaned references
# [2021-01-19 12:12:41.659] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2021-01-19 12:13:41.944] [puff::index::jointLog] [info] ntHll estimated 4973834330 distinct k-mers, setting filter size to 2^37
# Threads = 10
# Vertex length = 31
# Hash functions = 5
# Filter size = 137438953472
# Capacity = 2
# Files:
# ../../reference/human_mouse-hg19_mm10/salmon/salmon_index/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:137438953472
# Pass	Filling	Filtering
# 1	376	745
# 2	105	15
# True junctions count = 37339731
# False junctions count = 4954334
# Hash table size = 42294065
# Candidate marks count = 652239275
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 23
# True marks count: 646568950
# Edges construction time: 150
# --------------------------------------------------------------------------------
# Distinct junctions = 37339731
#
# allowedIn: 23
# Max Junction ID: 37343993
# seen.size():298751953 kmerInfo.size():37343994
# approximateContigTotalLength: 2514299284
# counters for complex kmers:
# (prec>1 & succ>1)=8450995 | (succ>1 & isStart)=2417 | (prec>1 & isEnd)=2505 | (isStart & isEnd)=118
# contig count: 62442640 element count: 6878138224 complex nodes: 8456035
# # of ones in rank vector: 62442639
# [2021-01-19 12:52:40.089] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2021-01-19 12:52:40.089] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory ../../reference/human_mouse-hg19_mm10/salmon/salmon_index
# size = 6878138224
# -----------------------------------------
# | Loading contigs | Time = 1.0681 s
# -----------------------------------------
# size = 6878138224
# -----------------------------------------
# | Loading contig boundaries | Time = 528.32 ms
# -----------------------------------------
# Number of ones: 62442639
# Number of ones per inventory item: 512
# Inventory entries filled: 121959
# 62442639
# [2021-01-19 12:52:55.099] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2021-01-19 12:52:56.092] [puff::index::jointLog] [info] contig count for validation: 62,442,639
# [2021-01-19 12:53:31.986] [puff::index::jointLog] [info] Total # of Contigs : 62,442,639
# [2021-01-19 12:53:31.986] [puff::index::jointLog] [info] Total # of numerical Contigs : 62,442,639
# [2021-01-19 12:53:36.949] [puff::index::jointLog] [info] Total # of contig vec entries: 669,407,337
# [2021-01-19 12:53:36.950] [puff::index::jointLog] [info] bits per offset entry 30
# [2021-01-19 12:54:20.774] [puff::index::jointLog] [info] Done constructing the contig vector. 62442640
# [2021-01-19 12:55:05.339] [puff::index::jointLog] [info] # segments = 62,442,639
# [2021-01-19 12:55:05.339] [puff::index::jointLog] [info] total length = 6,878,138,224
# [2021-01-19 12:55:06.300] [puff::index::jointLog] [info] Reading the reference files ...
# [2021-01-19 12:55:28.442] [puff::index::jointLog] [info] positional integer width = 33
# [2021-01-19 12:55:28.442] [puff::index::jointLog] [info] seqSize = 6,878,138,224
# [2021-01-19 12:55:28.442] [puff::index::jointLog] [info] rankSize = 6,878,138,224
# [2021-01-19 12:55:28.442] [puff::index::jointLog] [info] edgeVecSize = 0
# [2021-01-19 12:55:28.442] [puff::index::jointLog] [info] num keys = 5,004,859,054
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# [Building BooPHF]  99.8 %   elapsed:   2 min 43 sec   remaining:   0 min 0  sec
# Bitarray     26223855808  bits (100.00 %)   (array + ranks )
# final hash        914928  bits (0.00 %) (nb in final hash 2723)
# [2021-01-19 12:58:11.634] [puff::index::jointLog] [info] mphf size = 3126.24 MB
# [2021-01-19 12:58:22.535] [puff::index::jointLog] [info] chunk size = 687,813,823
# [2021-01-19 12:58:22.535] [puff::index::jointLog] [info] chunk 0 = [0, 687,813,823)
# [2021-01-19 12:58:22.535] [puff::index::jointLog] [info] chunk 1 = [687,813,823, 1,375,627,651)
# [2021-01-19 12:58:22.535] [puff::index::jointLog] [info] chunk 2 = [1,375,627,651, 2,063,441,488)
# [2021-01-19 12:58:22.535] [puff::index::jointLog] [info] chunk 3 = [2,063,441,488, 2,751,255,311)
# [2021-01-19 12:58:22.535] [puff::index::jointLog] [info] chunk 4 = [2,751,255,311, 3,439,069,134)
# [2021-01-19 12:58:22.535] [puff::index::jointLog] [info] chunk 5 = [3,439,069,134, 4,126,882,957)
# [2021-01-19 12:58:22.535] [puff::index::jointLog] [info] chunk 6 = [4,126,882,957, 4,814,696,780)
# [2021-01-19 12:58:22.535] [puff::index::jointLog] [info] chunk 7 = [4,814,696,780, 5,502,510,603)
# [2021-01-19 12:58:22.535] [puff::index::jointLog] [info] chunk 8 = [5,502,510,603, 6,190,324,426)
# [2021-01-19 12:58:22.535] [puff::index::jointLog] [info] chunk 9 = [6,190,324,426, 6,878,138,194)
# [2021-01-19 13:04:13.096] [puff::index::jointLog] [info] finished populating pos vector
# [2021-01-19 13:04:13.096] [puff::index::jointLog] [info] writing index components
# [2021-01-19 13:04:36.195] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2021-01-19 13:04:40.987] [jLog] [info] done building index
# [bash] making decoy t2g
# Done.

# %% [markdown]
# ## Mouse mm10

# %% [markdown]
# full-decoy

# %%
# !../scripts/mkref_salmon.sh \
-o ../../reference/mouse-mm10/salmon \
-g ../../reference/mouse-mm10/genome.fa \
-a ../../reference/mouse-mm10/genes.gtf \
-t ../../reference/mouse-mm10/transcriptome.fa \
-m ../../reference/mouse-mm10/t2g.txt
# Out:
# [bash] making gentrome and decoys
# [salmon] building decoy index
# Version Info: This is the most recent version of salmon.
# index ["../../reference/mouse-mm10/salmon/salmon_index"] did not previously exist  . . . creating it
# [2021-01-19 13:04:58.575] [jLog] [info] building index
# out : ../../reference/mouse-mm10/salmon/salmon_index
# [2021-01-19 13:04:58.575] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-01-19 13:04:59.945] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179520], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.945] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179883], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.945] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000195858], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.945] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179932], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.945] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000180001], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.945] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000178815], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.946] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000177965], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.946] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000178909], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.946] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000177646], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.946] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000178230], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.946] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000178483], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.946] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179262], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.946] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000178549], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.946] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000193012], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.946] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179166], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.946] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179560], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.946] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000177839], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.946] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000103439], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.946] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000180266], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:04:59.946] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000103441], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:00.131] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000231713], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:00.131] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000231466], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:00.190] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000226589], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:00.211] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000228114], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:00.227] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000226226], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:00.271] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000196221], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:00.271] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179664], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:00.271] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000177564], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:00.273] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000103739], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:00.350] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000226961], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:00.449] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000227223], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:00.520] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000226615], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:00.726] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000226153], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:00.756] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000227002], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:00.786] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000226172], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:01.322] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000229312], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:02.054] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179793], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:02.631] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000178537], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:02.631] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000178862], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:05:03.538] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000165700], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2021-01-19 13:05:47.591] [puff::index::jointLog] [warning] Removed 734 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-19 13:05:47.591] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2021-01-19 13:05:47.674] [puff::index::jointLog] [info] Replaced 78,088,277 non-ATCG nucleotides
# [2021-01-19 13:05:47.674] [puff::index::jointLog] [info] Clipped poly-A tails from 619 transcripts
# wrote 110376 cleaned references
# [2021-01-19 13:05:51.008] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2021-01-19 13:06:16.228] [puff::index::jointLog] [info] ntHll estimated 2271955431 distinct k-mers, setting filter size to 2^36
# Threads = 10
# Vertex length = 31
# Hash functions = 5
# Filter size = 68719476736
# Capacity = 2
# Files:
# ../../reference/mouse-mm10/salmon/salmon_index/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:68719476736
# Pass	Filling	Filtering
# 1	131	214
# 2	50	6
# True junctions count = 14884694
# False junctions count = 1211916
# Hash table size = 16096610
# Candidate marks count = 335984383
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 9
# True marks count: 334589115
# Edges construction time: 64
# --------------------------------------------------------------------------------
# Distinct junctions = 14884694
#
# allowedIn: 18
# Max Junction ID: 14886463
# seen.size():119091713 kmerInfo.size():14886464
# approximateContigTotalLength: 1099293420
# counters for complex kmers:
# (prec>1 & succ>1)=3124064 | (succ>1 & isStart)=637 | (prec>1 & isEnd)=603 | (isStart & isEnd)=31
# contig count: 24960917 element count: 3024077589 complex nodes: 3125335
# # of ones in rank vector: 24960916
# [2021-01-19 13:21:04.127] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2021-01-19 13:21:04.127] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory ../../reference/mouse-mm10/salmon/salmon_index
# size = 3024077589
# -----------------------------------------
# | Loading contigs | Time = 266.68 ms
# -----------------------------------------
# size = 3024077589
# -----------------------------------------
# | Loading contig boundaries | Time = 134.28 ms
# -----------------------------------------
# Number of ones: 24960916
# Number of ones per inventory item: 512
# Inventory entries filled: 48752
# 24960916
# [2021-01-19 13:21:10.492] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2021-01-19 13:21:10.821] [puff::index::jointLog] [info] contig count for validation: 24,960,916
# [2021-01-19 13:21:28.413] [puff::index::jointLog] [info] Total # of Contigs : 24,960,916
# [2021-01-19 13:21:28.413] [puff::index::jointLog] [info] Total # of numerical Contigs : 24,960,916
# [2021-01-19 13:21:29.983] [puff::index::jointLog] [info] Total # of contig vec entries: 344,341,396
# [2021-01-19 13:21:29.983] [puff::index::jointLog] [info] bits per offset entry 29
# [2021-01-19 13:21:37.511] [puff::index::jointLog] [info] Done constructing the contig vector. 24960917
# [2021-01-19 13:21:58.780] [puff::index::jointLog] [info] # segments = 24,960,916
# [2021-01-19 13:21:58.781] [puff::index::jointLog] [info] total length = 3,024,077,589
# [2021-01-19 13:21:58.988] [puff::index::jointLog] [info] Reading the reference files ...
# [2021-01-19 13:22:09.152] [puff::index::jointLog] [info] positional integer width = 32
# [2021-01-19 13:22:09.152] [puff::index::jointLog] [info] seqSize = 3,024,077,589
# [2021-01-19 13:22:09.152] [puff::index::jointLog] [info] rankSize = 3,024,077,589
# [2021-01-19 13:22:09.152] [puff::index::jointLog] [info] edgeVecSize = 0
# [2021-01-19 13:22:09.152] [puff::index::jointLog] [info] num keys = 2,275,250,109
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# [Building BooPHF]  100  %   elapsed:   1 min 8  sec   remaining:   0 min 0  sec
# Bitarray     11921586048  bits (100.00 %)   (array + ranks )
# final hash        240912  bits (0.00 %) (nb in final hash 717)
# [2021-01-19 13:23:16.868] [puff::index::jointLog] [info] mphf size = 1421.19 MB
# [2021-01-19 13:23:19.155] [puff::index::jointLog] [info] chunk size = 302,407,759
# [2021-01-19 13:23:19.155] [puff::index::jointLog] [info] chunk 0 = [0, 302,407,759)
# [2021-01-19 13:23:19.155] [puff::index::jointLog] [info] chunk 1 = [302,407,759, 604,815,518)
# [2021-01-19 13:23:19.155] [puff::index::jointLog] [info] chunk 2 = [604,815,518, 907,223,297)
# [2021-01-19 13:23:19.155] [puff::index::jointLog] [info] chunk 3 = [907,223,297, 1,209,631,056)
# [2021-01-19 13:23:19.155] [puff::index::jointLog] [info] chunk 4 = [1,209,631,056, 1,512,038,815)
# [2021-01-19 13:23:19.155] [puff::index::jointLog] [info] chunk 5 = [1,512,038,815, 1,814,446,574)
# [2021-01-19 13:23:19.155] [puff::index::jointLog] [info] chunk 6 = [1,814,446,574, 2,116,854,333)
# [2021-01-19 13:23:19.155] [puff::index::jointLog] [info] chunk 7 = [2,116,854,333, 2,419,262,092)
# [2021-01-19 13:23:19.155] [puff::index::jointLog] [info] chunk 8 = [2,419,262,092, 2,721,669,851)
# [2021-01-19 13:23:19.155] [puff::index::jointLog] [info] chunk 9 = [2,721,669,851, 3,024,077,559)
# [2021-01-19 13:24:47.959] [puff::index::jointLog] [info] finished populating pos vector
# [2021-01-19 13:24:47.959] [puff::index::jointLog] [info] writing index components
# [2021-01-19 13:24:56.429] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2021-01-19 13:24:56.948] [jLog] [info] done building index
# [bash] making decoy t2g
# Done.

# %% [markdown]
# ## Rat rnor6

# %%
# !../scripts/mkref_salmon.sh \
-o ../../reference/rat-rnor6/salmon \
-g ../../reference/rat-rnor6/genome.fa \
-a ../../reference/rat-rnor6/genes.gtf \
-t ../../reference/rat-rnor6/transcriptome.fa \
-m ../../reference/rat-rnor6/t2g.txt
# Out:
# [bash] making gentrome and decoys
# [salmon] building decoy index
# Version Info: This is the most recent version of salmon.
# [2021-01-20 10:31:57.619] [jLog] [info] building index
# out : ../../reference/rat-rnor6/salmon/salmon_index
# [2021-01-20 10:31:57.619] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-01-20 10:31:57.701] [puff::index::jointLog] [warning] Entry with header [ENSRNOT00000070100], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-20 10:31:58.413] [puff::index::jointLog] [warning] Entry with header [ENSRNOT00000093397], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-20 10:31:58.511] [puff::index::jointLog] [warning] Entry with header [ENSRNOT00000069362], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-20 10:31:58.634] [puff::index::jointLog] [warning] Entry with header [ENSRNOT00000069393], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-20 10:31:58.972] [puff::index::jointLog] [warning] Entry with header [ENSRNOT00000085980], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2021-01-20 10:33:18.474] [puff::index::jointLog] [warning] Removed 643 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-20 10:33:18.475] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2021-01-20 10:33:18.475] [puff::index::jointLog] [warning] There were 2 duplicate decoy sequences.
# [2021-01-20 10:33:18.518] [puff::index::jointLog] [info] Replaced 1,396,197,801 non-ATCG nucleotides
# [2021-01-20 10:33:18.519] [puff::index::jointLog] [info] Clipped poly-A tails from 0 transcripts
# wrote 41385 cleaned references
# [2021-01-20 10:33:24.475] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2021-01-20 10:33:49.854] [puff::index::jointLog] [info] ntHll estimated 2787408795 distinct k-mers, setting filter size to 2^36
# Threads = 10
# Vertex length = 31
# Hash functions = 5
# Filter size = 68719476736
# Capacity = 2
# Files:
# ../../reference/rat-rnor6/salmon/salmon_index/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:68719476736
# Pass	Filling	Filtering
# 1	156	285
# 2	48	2
# True junctions count = 1961278
# False junctions count = 6477453
# Hash table size = 8438731
# Candidate marks count = 19233229
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 1
# True marks count: 12454671
# Edges construction time: 51
# --------------------------------------------------------------------------------
# Distinct junctions = 1961278
#
# allowedIn: 18
# Max Junction ID: 1976527
# seen.size():15812225 kmerInfo.size():1976528
# approximateContigTotalLength: 1641433019
# counters for complex kmers:
# (prec>1 & succ>1)=89174 | (succ>1 & isStart)=199 | (prec>1 & isEnd)=203 | (isStart & isEnd)=2
# contig count: 3041270 element count: 2885302689 complex nodes: 89578
# # of ones in rank vector: 3041269
# [2021-01-20 10:47:55.403] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2021-01-20 10:47:55.404] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory ../../reference/rat-rnor6/salmon/salmon_index
# size = 2885302689
# -----------------------------------------
# | Loading contigs | Time = 505.43 ms
# -----------------------------------------
# size = 2885302689
# -----------------------------------------
# | Loading contig boundaries | Time = 303.02 ms
# -----------------------------------------
# Number of ones: 3041269
# Number of ones per inventory item: 512
# Inventory entries filled: 5940
# 3041269
# [2021-01-20 10:48:01.819] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2021-01-20 10:48:01.856] [puff::index::jointLog] [info] contig count for validation: 3,041,269
# [2021-01-20 10:48:02.538] [puff::index::jointLog] [info] Total # of Contigs : 3,041,269
# [2021-01-20 10:48:02.538] [puff::index::jointLog] [info] Total # of numerical Contigs : 3,041,269
# [2021-01-20 10:48:02.638] [puff::index::jointLog] [info] Total # of contig vec entries: 12,873,390
# [2021-01-20 10:48:02.638] [puff::index::jointLog] [info] bits per offset entry 24
# [2021-01-20 10:48:03.020] [puff::index::jointLog] [info] Done constructing the contig vector. 3041270
# [2021-01-20 10:48:04.310] [puff::index::jointLog] [info] # segments = 3,041,269
# [2021-01-20 10:48:04.310] [puff::index::jointLog] [info] total length = 2,885,302,689
# [2021-01-20 10:48:04.966] [puff::index::jointLog] [info] Reading the reference files ...
# [2021-01-20 10:48:18.613] [puff::index::jointLog] [info] positional integer width = 32
# [2021-01-20 10:48:18.613] [puff::index::jointLog] [info] seqSize = 2,885,302,689
# [2021-01-20 10:48:18.613] [puff::index::jointLog] [info] rankSize = 2,885,302,689
# [2021-01-20 10:48:18.613] [puff::index::jointLog] [info] edgeVecSize = 0
# [2021-01-20 10:48:18.613] [puff::index::jointLog] [info] num keys = 2,794,064,619
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# [Building BooPHF]  99.9 %   elapsed:   1 min 29 sec   remaining:   0 min 0  sec
# Bitarray     14640006336  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# [2021-01-20 10:49:47.718] [puff::index::jointLog] [info] mphf size = 1745.22 MB
# [2021-01-20 10:49:53.836] [puff::index::jointLog] [info] chunk size = 288,530,269
# [2021-01-20 10:49:53.836] [puff::index::jointLog] [info] chunk 0 = [0, 288,530,269)
# [2021-01-20 10:49:53.836] [puff::index::jointLog] [info] chunk 1 = [288,530,269, 577,060,538)
# [2021-01-20 10:49:53.836] [puff::index::jointLog] [info] chunk 2 = [577,060,538, 865,590,807)
# [2021-01-20 10:49:53.836] [puff::index::jointLog] [info] chunk 3 = [865,590,807, 1,154,121,076)
# [2021-01-20 10:49:53.836] [puff::index::jointLog] [info] chunk 4 = [1,154,121,076, 1,442,651,345)
# [2021-01-20 10:49:53.836] [puff::index::jointLog] [info] chunk 5 = [1,442,651,345, 1,731,181,614)
# [2021-01-20 10:49:53.845] [puff::index::jointLog] [info] chunk 6 = [1,731,181,614, 2,019,711,883)
# [2021-01-20 10:49:53.845] [puff::index::jointLog] [info] chunk 7 = [2,019,711,883, 2,308,242,152)
# [2021-01-20 10:49:53.845] [puff::index::jointLog] [info] chunk 8 = [2,308,242,152, 2,596,772,421)
# [2021-01-20 10:49:53.845] [puff::index::jointLog] [info] chunk 9 = [2,596,772,421, 2,885,302,659)
# [2021-01-20 10:52:32.463] [puff::index::jointLog] [info] finished populating pos vector
# [2021-01-20 10:52:32.468] [puff::index::jointLog] [info] writing index components
# [2021-01-20 10:53:05.480] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2021-01-20 10:53:08.068] [jLog] [info] done building index
# [bash] making decoy t2g
# Done.

# %% [markdown]
# ## Zebrafish dr82

# %%
# !../scripts/mkref_salmon.sh \
-o ../../reference/zebrafish-dr82/salmon \
-g ../../reference/zebrafish-dr82/genome.fa \
-a ../../reference/zebrafish-dr82/genes.gtf \
-t ../../reference/zebrafish-dr82/transcriptome.fa \
-m ../../reference/zebrafish-dr82/t2g.txt
# Out:
# [bash] making gentrome and decoys
# [salmon] building decoy index
# Version Info: This is the most recent version of salmon.
# [2021-01-20 10:53:22.382] [jLog] [info] building index
# out : ../../reference/zebrafish-dr82/salmon/salmon_index
# [2021-01-20 10:53:22.383] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-01-20 10:53:23.772] [puff::index::jointLog] [warning] Entry with header [ENSDART00000171117], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-20 10:53:23.772] [puff::index::jointLog] [warning] Entry with header [ENSDART00000162914], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-20 10:53:24.410] [puff::index::jointLog] [warning] Entry with header [ENSDART00000151250], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-20 10:53:24.410] [puff::index::jointLog] [warning] Entry with header [ENSDART00000151491], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-20 10:53:24.410] [puff::index::jointLog] [warning] Entry with header [ENSDART00000150889], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-20 10:53:24.410] [puff::index::jointLog] [warning] Entry with header [ENSDART00000151572], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-20 10:53:24.410] [puff::index::jointLog] [warning] Entry with header [ENSDART00000151686], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-20 10:53:24.410] [puff::index::jointLog] [warning] Entry with header [ENSDART00000151215], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-20 10:53:24.410] [puff::index::jointLog] [warning] Entry with header [ENSDART00000151691], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2021-01-20 10:53:58.960] [puff::index::jointLog] [warning] Removed 1024 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-20 10:53:58.960] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2021-01-20 10:53:58.984] [puff::index::jointLog] [info] Replaced 771,586,625 non-ATCG nucleotides
# [2021-01-20 10:53:58.984] [puff::index::jointLog] [info] Clipped poly-A tails from 2 transcripts
# wrote 57397 cleaned references
# [2021-01-20 10:54:01.571] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2021-01-20 10:54:14.687] [puff::index::jointLog] [info] ntHll estimated 1356001422 distinct k-mers, setting filter size to 2^35
# Threads = 10
# Vertex length = 31
# Hash functions = 5
# Filter size = 34359738368
# Capacity = 2
# Files:
# ../../reference/zebrafish-dr82/salmon/salmon_index/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:34359738368
# Pass	Filling	Filtering
# 1	75	125
# 2	22	1
# True junctions count = 1922502
# False junctions count = 1616611
# Hash table size = 3539113
# Candidate marks count = 15315579
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 13595304
# Edges construction time: 23
# --------------------------------------------------------------------------------
# Distinct junctions = 1922502
#
# allowedIn: 18
# Max Junction ID: 1944323
# seen.size():15554593 kmerInfo.size():1944324
# approximateContigTotalLength: 808379059
# counters for complex kmers:
# (prec>1 & succ>1)=138054 | (succ>1 & isStart)=266 | (prec>1 & isEnd)=301 | (isStart & isEnd)=6
# contig count: 3024697 element count: 1448468199 complex nodes: 138627
# # of ones in rank vector: 3024696
# [2021-01-20 11:00:15.607] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2021-01-20 11:00:15.607] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory ../../reference/zebrafish-dr82/salmon/salmon_index
# size = 1448468199
# -----------------------------------------
# | Loading contigs | Time = 161.77 ms
# -----------------------------------------
# size = 1448468199
# -----------------------------------------
# | Loading contig boundaries | Time = 77.779 ms
# -----------------------------------------
# Number of ones: 3024696
# Number of ones per inventory item: 512
# Inventory entries filled: 5908
# 3024696
# [2021-01-20 11:00:18.524] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2021-01-20 11:00:18.557] [puff::index::jointLog] [info] contig count for validation: 3,024,696
# [2021-01-20 11:00:19.316] [puff::index::jointLog] [info] Total # of Contigs : 3,024,696
# [2021-01-20 11:00:19.316] [puff::index::jointLog] [info] Total # of numerical Contigs : 3,024,696
# [2021-01-20 11:00:19.401] [puff::index::jointLog] [info] Total # of contig vec entries: 13,998,481
# [2021-01-20 11:00:19.401] [puff::index::jointLog] [info] bits per offset entry 24
# [2021-01-20 11:00:19.786] [puff::index::jointLog] [info] Done constructing the contig vector. 3024697
# [2021-01-20 11:00:21.144] [puff::index::jointLog] [info] # segments = 3,024,696
# [2021-01-20 11:00:21.144] [puff::index::jointLog] [info] total length = 1,448,468,199
# [2021-01-20 11:00:21.271] [puff::index::jointLog] [info] Reading the reference files ...
# [2021-01-20 11:00:26.859] [puff::index::jointLog] [info] positional integer width = 31
# [2021-01-20 11:00:26.859] [puff::index::jointLog] [info] seqSize = 1,448,468,199
# [2021-01-20 11:00:26.859] [puff::index::jointLog] [info] rankSize = 1,448,468,199
# [2021-01-20 11:00:26.859] [puff::index::jointLog] [info] edgeVecSize = 0
# [2021-01-20 11:00:26.859] [puff::index::jointLog] [info] num keys = 1,357,727,319
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# [Building BooPHF]  100  %   elapsed:   0 min 40 sec   remaining:   0 min 0  sec
# Bitarray      7114061120  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# [2021-01-20 11:01:07.146] [puff::index::jointLog] [info] mphf size = 848.062 MB
# [2021-01-20 11:01:09.119] [puff::index::jointLog] [info] chunk size = 144,846,820
# [2021-01-20 11:01:09.119] [puff::index::jointLog] [info] chunk 0 = [0, 144,846,820)
# [2021-01-20 11:01:09.119] [puff::index::jointLog] [info] chunk 1 = [144,846,820, 289,693,666)
# [2021-01-20 11:01:09.119] [puff::index::jointLog] [info] chunk 2 = [289,693,666, 434,540,486)
# [2021-01-20 11:01:09.119] [puff::index::jointLog] [info] chunk 3 = [434,540,486, 579,387,306)
# [2021-01-20 11:01:09.119] [puff::index::jointLog] [info] chunk 4 = [579,387,306, 724,234,126)
# [2021-01-20 11:01:09.119] [puff::index::jointLog] [info] chunk 5 = [724,234,126, 869,080,946)
# [2021-01-20 11:01:09.119] [puff::index::jointLog] [info] chunk 6 = [869,080,946, 1,013,927,766)
# [2021-01-20 11:01:09.119] [puff::index::jointLog] [info] chunk 7 = [1,013,927,766, 1,158,774,586)
# [2021-01-20 11:01:09.119] [puff::index::jointLog] [info] chunk 8 = [1,158,774,586, 1,303,621,406)
# [2021-01-20 11:01:09.119] [puff::index::jointLog] [info] chunk 9 = [1,303,621,406, 1,448,468,169)
# [2021-01-20 11:02:09.994] [puff::index::jointLog] [info] finished populating pos vector
# [2021-01-20 11:02:09.994] [puff::index::jointLog] [info] writing index components
# [2021-01-20 11:02:25.561] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2021-01-20 11:02:26.391] [jLog] [info] done building index
# [bash] making decoy t2g
# Done.

# %% [markdown]
# ## Arabidopsis tair10

# %%
# !../scripts/mkref_salmon.sh \
-o ../../reference/arabidopsis-tair10/salmon \
-g ../../reference/arabidopsis-tair10/genome.fa \
-a ../../reference/arabidopsis-tair10/genes.gtf \
-t ../../reference/arabidopsis-tair10/transcriptome.fa \
-m ../../reference/arabidopsis-tair10/t2g.txt
# Out:
# [bash] making gentrome and decoys
# [salmon] building decoy index
# Version Info: This is the most recent version of salmon.
# index ["../../reference/arabidopsis-tair10/salmon/salmon_index"] did not previously exist  . . . creating it
# [2021-01-19 13:50:27.926] [jLog] [info] building index
# out : ../../reference/arabidopsis-tair10/salmon/salmon_index
# [2021-01-19 13:50:27.926] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-01-19 13:50:29.771] [puff::index::jointLog] [warning] Entry with header [ATMG00665.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2021-01-19 13:50:31.536] [puff::index::jointLog] [warning] Removed 585 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-19 13:50:31.536] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2021-01-19 13:50:31.537] [puff::index::jointLog] [info] Replaced 186,904 non-ATCG nucleotides
# [2021-01-19 13:50:31.537] [puff::index::jointLog] [info] Clipped poly-A tails from 24 transcripts
# wrote 41092 cleaned references
# [2021-01-19 13:50:31.804] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2021-01-19 13:50:33.303] [puff::index::jointLog] [info] ntHll estimated 115062848 distinct k-mers, setting filter size to 2^31
# Threads = 10
# Vertex length = 31
# Hash functions = 5
# Filter size = 2147483648
# Capacity = 2
# Files:
# ../../reference/arabidopsis-tair10/salmon/salmon_index/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:2147483648
# Pass	Filling	Filtering
# 1	7	13
# 2	3	0
# True junctions count = 683886
# False junctions count = 1247683
# Hash table size = 1931569
# Candidate marks count = 6082152
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 3689622
# Edges construction time: 3
# --------------------------------------------------------------------------------
# Distinct junctions = 683886
#
# allowedIn: 12
# Max Junction ID: 684511
# seen.size():5476097 kmerInfo.size():684512
# approximateContigTotalLength: 95341986
# counters for complex kmers:
# (prec>1 & succ>1)=28747 | (succ>1 & isStart)=121 | (prec>1 & isEnd)=127 | (isStart & isEnd)=15
# contig count: 1020998 element count: 146220496 complex nodes: 29010
# # of ones in rank vector: 1020997
# [2021-01-19 13:51:14.909] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2021-01-19 13:51:14.909] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory ../../reference/arabidopsis-tair10/salmon/salmon_index
# size = 146220496
# -----------------------------------------
# | Loading contigs | Time = 13.662 ms
# -----------------------------------------
# size = 146220496
# -----------------------------------------
# | Loading contig boundaries | Time = 7.1543 ms
# -----------------------------------------
# Number of ones: 1020997
# Number of ones per inventory item: 512
# Inventory entries filled: 1995
# 1020997
# [2021-01-19 13:51:15.217] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2021-01-19 13:51:15.229] [puff::index::jointLog] [info] contig count for validation: 1,020,997
# [2021-01-19 13:51:15.433] [puff::index::jointLog] [info] Total # of Contigs : 1,020,997
# [2021-01-19 13:51:15.433] [puff::index::jointLog] [info] Total # of numerical Contigs : 1,020,997
# [2021-01-19 13:51:15.455] [puff::index::jointLog] [info] Total # of contig vec entries: 3,772,609
# [2021-01-19 13:51:15.455] [puff::index::jointLog] [info] bits per offset entry 22
# [2021-01-19 13:51:15.518] [puff::index::jointLog] [info] Done constructing the contig vector. 1020998
# [2021-01-19 13:51:15.757] [puff::index::jointLog] [info] # segments = 1,020,997
# [2021-01-19 13:51:15.757] [puff::index::jointLog] [info] total length = 146,220,496
# [2021-01-19 13:51:15.774] [puff::index::jointLog] [info] Reading the reference files ...
# [2021-01-19 13:51:16.369] [puff::index::jointLog] [info] positional integer width = 28
# [2021-01-19 13:51:16.369] [puff::index::jointLog] [info] seqSize = 146,220,496
# [2021-01-19 13:51:16.369] [puff::index::jointLog] [info] rankSize = 146,220,496
# [2021-01-19 13:51:16.369] [puff::index::jointLog] [info] edgeVecSize = 0
# [2021-01-19 13:51:16.369] [puff::index::jointLog] [info] num keys = 115,590,586
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# [Building BooPHF]  100  %   elapsed:   0 min 3  sec   remaining:   0 min 0  sec
# Bitarray       605663232  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# [2021-01-19 13:51:19.272] [puff::index::jointLog] [info] mphf size = 72.2007 MB
# [2021-01-19 13:51:19.391] [puff::index::jointLog] [info] chunk size = 14,622,050
# [2021-01-19 13:51:19.391] [puff::index::jointLog] [info] chunk 0 = [0, 14,622,050)
# [2021-01-19 13:51:19.391] [puff::index::jointLog] [info] chunk 1 = [14,622,050, 29,244,100)
# [2021-01-19 13:51:19.391] [puff::index::jointLog] [info] chunk 2 = [29,244,100, 43,866,150)
# [2021-01-19 13:51:19.391] [puff::index::jointLog] [info] chunk 3 = [43,866,150, 58,488,200)
# [2021-01-19 13:51:19.391] [puff::index::jointLog] [info] chunk 4 = [58,488,200, 73,110,250)
# [2021-01-19 13:51:19.391] [puff::index::jointLog] [info] chunk 5 = [73,110,250, 87,732,300)
# [2021-01-19 13:51:19.391] [puff::index::jointLog] [info] chunk 6 = [87,732,300, 102,354,350)
# [2021-01-19 13:51:19.391] [puff::index::jointLog] [info] chunk 7 = [102,354,350, 116,976,400)
# [2021-01-19 13:51:19.391] [puff::index::jointLog] [info] chunk 8 = [116,976,400, 131,598,450)
# [2021-01-19 13:51:19.391] [puff::index::jointLog] [info] chunk 9 = [131,598,450, 146,220,466)
# [2021-01-19 13:51:23.192] [puff::index::jointLog] [info] finished populating pos vector
# [2021-01-19 13:51:23.192] [puff::index::jointLog] [info] writing index components
# [2021-01-19 13:51:23.659] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2021-01-19 13:51:23.709] [jLog] [info] done building index
# [bash] making decoy t2g
# Done.

# %% [markdown]
# ## Fly dm6

# %%
# !../scripts/mkref_salmon.sh \
-o ../../reference/fly-dm6/salmon \
-g ../../reference/fly-dm6/genome.fa \
-a ../../reference/fly-dm6/genes.gtf \
-t ../../reference/fly-dm6/transcriptome.fa \
-m ../../reference/fly-dm6/t2g.txt
# Out:
# [bash] making gentrome and decoys
# [salmon] building decoy index
# Version Info: This is the most recent version of salmon.
# index ["../../reference/fly-dm6/salmon/salmon_index"] did not previously exist  . . . creating it
# [2021-01-19 13:51:29.798] [jLog] [info] building index
# out : ../../reference/fly-dm6/salmon/salmon_index
# [2021-01-19 13:51:29.798] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-01-19 13:51:30.427] [puff::index::jointLog] [warning] Entry with header [FBtr0091693], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:51:32.116] [puff::index::jointLog] [warning] Entry with header [FBtr0346890], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:51:32.116] [puff::index::jointLog] [warning] Entry with header [FBtr0346894], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:51:32.116] [puff::index::jointLog] [warning] Entry with header [FBtr0346898], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:51:32.153] [puff::index::jointLog] [warning] Entry with header [FBtr0346870], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:51:32.153] [puff::index::jointLog] [warning] Entry with header [FBtr0346875], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:51:32.154] [puff::index::jointLog] [warning] Entry with header [FBtr0346880], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-19 13:51:32.154] [puff::index::jointLog] [warning] Entry with header [FBtr0346884], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2021-01-19 13:51:34.224] [puff::index::jointLog] [warning] Removed 1100 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-19 13:51:34.224] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2021-01-19 13:51:34.225] [puff::index::jointLog] [info] Replaced 1,152,978 non-ATCG nucleotides
# [2021-01-19 13:51:34.225] [puff::index::jointLog] [info] Clipped poly-A tails from 10 transcripts
# wrote 35276 cleaned references
# [2021-01-19 13:51:34.531] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2021-01-19 13:51:36.315] [puff::index::jointLog] [info] ntHll estimated 124768769 distinct k-mers, setting filter size to 2^32
# Threads = 10
# Vertex length = 31
# Hash functions = 5
# Filter size = 4294967296
# Capacity = 2
# Files:
# ../../reference/fly-dm6/salmon/salmon_index/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:4294967296
# Pass	Filling	Filtering
# 1	10	14
# 2	3	1
# True junctions count = 448879
# False junctions count = 44842
# Hash table size = 493721
# Candidate marks count = 5861260
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 5781516
# Edges construction time: 4
# --------------------------------------------------------------------------------
# Distinct junctions = 448879
#
# allowedIn: 41
# Max Junction ID: 450305
# seen.size():3602449 kmerInfo.size():450306
# approximateContigTotalLength: 101635167
# counters for complex kmers:
# (prec>1 & succ>1)=28343 | (succ>1 & isStart)=156 | (prec>1 & isEnd)=149 | (isStart & isEnd)=10
# contig count: 680814 element count: 145603579 complex nodes: 28658
# # of ones in rank vector: 680813
# [2021-01-19 13:52:25.819] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2021-01-19 13:52:25.819] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory ../../reference/fly-dm6/salmon/salmon_index
# size = 145603579
# -----------------------------------------
# | Loading contigs | Time = 14.571 ms
# -----------------------------------------
# size = 145603579
# -----------------------------------------
# | Loading contig boundaries | Time = 7.6749 ms
# -----------------------------------------
# Number of ones: 680813
# Number of ones per inventory item: 512
# Inventory entries filled: 1330
# 680813
# [2021-01-19 13:52:26.130] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2021-01-19 13:52:26.141] [puff::index::jointLog] [info] contig count for validation: 680,813
# [2021-01-19 13:52:26.452] [puff::index::jointLog] [info] Total # of Contigs : 680,813
# [2021-01-19 13:52:26.452] [puff::index::jointLog] [info] Total # of numerical Contigs : 680,813
# [2021-01-19 13:52:26.477] [puff::index::jointLog] [info] Total # of contig vec entries: 5,893,948
# [2021-01-19 13:52:26.477] [puff::index::jointLog] [info] bits per offset entry 23
# [2021-01-19 13:52:26.562] [puff::index::jointLog] [info] Done constructing the contig vector. 680814
# [2021-01-19 13:52:26.943] [puff::index::jointLog] [info] # segments = 680,813
# [2021-01-19 13:52:26.943] [puff::index::jointLog] [info] total length = 145,603,579
# [2021-01-19 13:52:26.965] [puff::index::jointLog] [info] Reading the reference files ...
# [2021-01-19 13:52:27.696] [puff::index::jointLog] [info] positional integer width = 28
# [2021-01-19 13:52:27.696] [puff::index::jointLog] [info] seqSize = 145,603,579
# [2021-01-19 13:52:27.696] [puff::index::jointLog] [info] rankSize = 145,603,579
# [2021-01-19 13:52:27.696] [puff::index::jointLog] [info] edgeVecSize = 0
# [2021-01-19 13:52:27.696] [puff::index::jointLog] [info] num keys = 125,179,189
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# [Building BooPHF]  100  %   elapsed:   0 min 3  sec   remaining:   0 min 0  sec
# Bitarray       655904512  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# [2021-01-19 13:52:30.870] [puff::index::jointLog] [info] mphf size = 78.1899 MB
# [2021-01-19 13:52:30.992] [puff::index::jointLog] [info] chunk size = 14,560,358
# [2021-01-19 13:52:30.992] [puff::index::jointLog] [info] chunk 0 = [0, 14,560,358)
# [2021-01-19 13:52:30.992] [puff::index::jointLog] [info] chunk 1 = [14,560,358, 29,120,716)
# [2021-01-19 13:52:30.992] [puff::index::jointLog] [info] chunk 2 = [29,120,716, 43,681,074)
# [2021-01-19 13:52:30.992] [puff::index::jointLog] [info] chunk 3 = [43,681,074, 58,241,456)
# [2021-01-19 13:52:30.992] [puff::index::jointLog] [info] chunk 4 = [58,241,456, 72,801,814)
# [2021-01-19 13:52:30.992] [puff::index::jointLog] [info] chunk 5 = [72,801,814, 87,362,172)
# [2021-01-19 13:52:30.992] [puff::index::jointLog] [info] chunk 6 = [87,362,172, 101,922,535)
# [2021-01-19 13:52:30.992] [puff::index::jointLog] [info] chunk 7 = [101,922,535, 116,482,893)
# [2021-01-19 13:52:30.992] [puff::index::jointLog] [info] chunk 8 = [116,482,893, 131,043,251)
# [2021-01-19 13:52:30.992] [puff::index::jointLog] [info] chunk 9 = [131,043,251, 145,603,549)
# [2021-01-19 13:52:34.886] [puff::index::jointLog] [info] finished populating pos vector
# [2021-01-19 13:52:34.887] [puff::index::jointLog] [info] writing index components
# [2021-01-19 13:52:35.294] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2021-01-19 13:52:35.352] [jLog] [info] done building index
# [bash] making decoy t2g
# Done.

# %% [markdown]
# ## Worm ws260

# %%
# !../scripts/mkref_salmon.sh \
-o ../../reference/worm-ws260/salmon \
-g ../../reference/worm-ws260/genome.fa \
-a ../../reference/worm-ws260/genes.gtf \
-t ../../reference/worm-ws260/transcriptome.fa \
-m ../../reference/worm-ws260/t2g.txt
# Out:
# [bash] making gentrome and decoys
# [salmon] building decoy index
# Version Info: This is the most recent version of salmon.
# index ["../../reference/worm-ws260/salmon/salmon_index"] did not previously exist  . . . creating it
# [2021-01-19 13:52:41.302] [jLog] [info] building index
# out : ../../reference/worm-ws260/salmon/salmon_index
# [2021-01-19 13:52:41.302] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-01-19 13:52:42.240] [puff::index::jointLog] [warning] Entry with header [W03F8.6d], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2021-01-19 13:52:44.360] [puff::index::jointLog] [warning] Removed 366 transcripts that were sequence duplicates of indexed transcripts.
# [2021-01-19 13:52:44.360] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2021-01-19 13:52:44.360] [puff::index::jointLog] [info] Replaced 0 non-ATCG nucleotides
# [2021-01-19 13:52:44.360] [puff::index::jointLog] [info] Clipped poly-A tails from 20 transcripts
# wrote 33675 cleaned references
# [2021-01-19 13:52:44.586] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2021-01-19 13:52:45.920] [puff::index::jointLog] [info] ntHll estimated 97393849 distinct k-mers, setting filter size to 2^31
# Threads = 10
# Vertex length = 31
# Hash functions = 5
# Filter size = 2147483648
# Capacity = 2
# Files:
# ../../reference/worm-ws260/salmon/salmon_index/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:2147483648
# Pass	Filling	Filtering
# 1	7	10
# 2	3	0
# True junctions count = 512233
# False junctions count = 784142
# Hash table size = 1296375
# Candidate marks count = 4318753
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 2858498
# Edges construction time: 3
# --------------------------------------------------------------------------------
# Distinct junctions = 512233
#
# allowedIn: 14
# Max Junction ID: 513300
# seen.size():4106409 kmerInfo.size():513301
# approximateContigTotalLength: 78285222
# counters for complex kmers:
# (prec>1 & succ>1)=28550 | (succ>1 & isStart)=68 | (prec>1 & isEnd)=69 | (isStart & isEnd)=17
# contig count: 771693 element count: 120291649 complex nodes: 28704
# # of ones in rank vector: 771692
# [2021-01-19 13:53:21.537] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2021-01-19 13:53:21.537] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory ../../reference/worm-ws260/salmon/salmon_index
# size = 120291649
# -----------------------------------------
# | Loading contigs | Time = 11.793 ms
# -----------------------------------------
# size = 120291649
# -----------------------------------------
# | Loading contig boundaries | Time = 6.443 ms
# -----------------------------------------
# Number of ones: 771692
# Number of ones per inventory item: 512
# Inventory entries filled: 1508
# 771692
# [2021-01-19 13:53:21.794] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2021-01-19 13:53:21.802] [puff::index::jointLog] [info] contig count for validation: 771,692
# [2021-01-19 13:53:21.958] [puff::index::jointLog] [info] Total # of Contigs : 771,692
# [2021-01-19 13:53:21.958] [puff::index::jointLog] [info] Total # of numerical Contigs : 771,692
# [2021-01-19 13:53:21.976] [puff::index::jointLog] [info] Total # of contig vec entries: 2,913,380
# [2021-01-19 13:53:21.976] [puff::index::jointLog] [info] bits per offset entry 22
# [2021-01-19 13:53:22.022] [puff::index::jointLog] [info] Done constructing the contig vector. 771693
# [2021-01-19 13:53:22.212] [puff::index::jointLog] [info] # segments = 771,692
# [2021-01-19 13:53:22.212] [puff::index::jointLog] [info] total length = 120,291,649
# [2021-01-19 13:53:22.230] [puff::index::jointLog] [info] Reading the reference files ...
# [2021-01-19 13:53:22.881] [puff::index::jointLog] [info] positional integer width = 27
# [2021-01-19 13:53:22.881] [puff::index::jointLog] [info] seqSize = 120,291,649
# [2021-01-19 13:53:22.881] [puff::index::jointLog] [info] rankSize = 120,291,649
# [2021-01-19 13:53:22.881] [puff::index::jointLog] [info] edgeVecSize = 0
# [2021-01-19 13:53:22.881] [puff::index::jointLog] [info] num keys = 97,140,889
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# [Building BooPHF]  100  %   elapsed:   0 min 2  sec   remaining:   0 min 0  sec
# Bitarray       508993024  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# [2021-01-19 13:53:25.368] [puff::index::jointLog] [info] mphf size = 60.6767 MB
# [2021-01-19 13:53:25.473] [puff::index::jointLog] [info] chunk size = 12,029,165
# [2021-01-19 13:53:25.473] [puff::index::jointLog] [info] chunk 0 = [0, 12,029,165)
# [2021-01-19 13:53:25.473] [puff::index::jointLog] [info] chunk 1 = [12,029,165, 24,058,339)
# [2021-01-19 13:53:25.473] [puff::index::jointLog] [info] chunk 2 = [24,058,339, 36,087,504)
# [2021-01-19 13:53:25.473] [puff::index::jointLog] [info] chunk 3 = [36,087,504, 48,116,669)
# [2021-01-19 13:53:25.473] [puff::index::jointLog] [info] chunk 4 = [48,116,669, 60,145,834)
# [2021-01-19 13:53:25.473] [puff::index::jointLog] [info] chunk 5 = [60,145,834, 72,174,999)
# [2021-01-19 13:53:25.473] [puff::index::jointLog] [info] chunk 6 = [72,174,999, 84,204,164)
# [2021-01-19 13:53:25.473] [puff::index::jointLog] [info] chunk 7 = [84,204,164, 96,233,329)
# [2021-01-19 13:53:25.473] [puff::index::jointLog] [info] chunk 8 = [96,233,329, 108,262,494)
# [2021-01-19 13:53:25.473] [puff::index::jointLog] [info] chunk 9 = [108,262,494, 120,291,619)
# [2021-01-19 13:53:28.402] [puff::index::jointLog] [info] finished populating pos vector
# [2021-01-19 13:53:28.403] [puff::index::jointLog] [info] writing index components
# [2021-01-19 13:53:28.769] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2021-01-19 13:53:28.811] [jLog] [info] done building index
# [bash] making decoy t2g
# Done.
