# %%
# !date
# Out:
# Thu Jan 14 21:13:08 PST 2021

# %% [markdown]
# # Quantify with salmon alevin and alevin-fried

# %% [markdown]
# ### Dataset

# %% [markdown]
# ```
# ref   ../../reference/mouse-mm10/
# out   ../../data/kallisto_out/mouse-SRR8206317_v2
# fastq ../../data/fastqs/mouse-SRR8206317_v2
#
# whitelist ../../reference/whitelist_10xv2.txt
# ```

# %%
# %%bash
# FASTQDIR="../../data/fastqs/mouse-SRR8206317_v2/" && \
# OUTDIR="../../data/alevin_out/mouse-SRR8206317_v2" && \
# INDEX="../../reference/mouse-mm10/salmon" && \
# T2G='../../reference/mouse-mm10/alevin_t2g.txt' && \
# time salmon alevin \
# -l ISR \
# -i $INDEX \
# -1 $(ls $FASTQDIR | awk -v p=$FASTQDIR '{print p$0}' | grep R1) \
# -2 $(ls $FASTQDIR | awk -v p=$FASTQDIR '{print p$0}' | grep R2) \
# --tgMap $T2G \
# -o $OUTDIR \
# --rad \
# -p 1 \
# --chromium
# Out:
# Version Info: This is the most recent version of salmon.
# [2021-01-14 21:35:47.449] [alevinLog] [info] The --rad flag was passed to alevin. The reads will be selectively aligned and the output written to a RAD file.Arguments passed that correspond to other processing steps will be ignored
# Logs will be written to ../../data/alevin_out/mouse-SRR8206317_v2/logs
# [2021-01-14 21:35:47.470] [jointLog] [info] setting maxHashResizeThreads to 8
# [2021-01-14 21:35:47.470] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-01-14 21:35:47.470] [jointLog] [info] The --mimicBT2, --mimicStrictBT2 and --hardFilter flags imply mapping validation (--validateMappings). Enabling mapping validation.
# [2021-01-14 21:35:47.470] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2021-01-14 21:35:47.470] [jointLog] [info] The use of range-factorized equivalence classes does not make sense in conjunction with --hardFilter.  Disabling range-factorized equivalence classes.
# [2021-01-14 21:35:47.470] [jointLog] [info] Setting consensusSlack to selective-alignment default of 0.35.
# [2021-01-14 21:35:47.470] [jointLog] [info] Using default value of 0.87 for minScoreFraction in Alevin
# Using default value of 0.6 for consensusSlack in Alevin
# [2021-01-14 21:35:47.571] [alevinLog] [info] Found 110310 transcripts(+0 decoys, +35 short and +0 duplicate names in the index)
# [2021-01-14 21:35:47.662] [alevinLog] [info] Filled with 110345 txp to gene entries
# ### alevin (dscRNA-seq quantification) v1.4.0
# ### [ program ] => salmon
# ### [ command ] => alevin
# ### [ libType ] => { ISR }
# ### [ index ] => { ../../reference/mouse-mm10/salmon }
# ### [ mates1 ] => { ../../data/fastqs/mouse-SRR8206317_v2/bamtofastq_S1_L001_R1_001.fastq.gz ../../data/fastqs/mouse-SRR8206317_v2/bamtofastq_S1_L002_R1_001.fastq.gz ../../data/fastqs/mouse-SRR8206317_v2/bamtofastq_S1_L003_R1_001.fastq.gz ../../data/fastqs/mouse-SRR8206317_v2/bamtofastq_S1_L004_R1_001.fastq.gz }
# ### [ mates2 ] => { ../../data/fastqs/mouse-SRR8206317_v2/bamtofastq_S1_L001_R2_001.fastq.gz ../../data/fastqs/mouse-SRR8206317_v2/bamtofastq_S1_L002_R2_001.fastq.gz ../../data/fastqs/mouse-SRR8206317_v2/bamtofastq_S1_L003_R2_001.fastq.gz ../../data/fastqs/mouse-SRR8206317_v2/bamtofastq_S1_L004_R2_001.fastq.gz }
# ### [ tgMap ] => { ../../reference/mouse-mm10/alevin_t2g.txt }
# ### [ output ] => { ../../data/alevin_out/mouse-SRR8206317_v2 }
# ### [ rad ] => { }
# ### [ threads ] => { 8 }
# ### [ chromium ] => { }
#
#
# [2021-01-14 21:35:47.677] [alevinLog] [info] Found all transcripts to gene mappings
# [2021-01-14 21:35:47.687] [alevinLog] [info] parsing read library format
# -----------------------------------------
# | Loading contig table | Time = 235.83 ms
# -----------------------------------------
# size = 578970
# -----------------------------------------
# | Loading contig offsets | Time = 25.149 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 162.13 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 83.379 ms
# -----------------------------------------
# size = 119564461
# Number of ones: 578969
# Number of ones per inventory item: 512
# [2021-01-14 21:35:47.687] [jointLog] [info] There is 1 library.
# [2021-01-14 21:35:47.757] [jointLog] [info] Loading pufferfish index
# [2021-01-14 21:35:47.757] [jointLog] [info] Loading dense pufferfish index.
# Inventory entries filled: 1131
# -----------------------------------------
# | Loading contig boundaries | Time = 270.93 ms
# -----------------------------------------
# size = 119564461
# -----------------------------------------
# | Loading sequence | Time = 53.057 ms
# -----------------------------------------
# size = 102195391
# -----------------------------------------
# | Loading positions | Time = 285.53 ms
# -----------------------------------------
# size = 208727907
# -----------------------------------------
# | Loading reference sequence | Time = 43.949 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 17.91 ms
# -----------------------------------------
# [2021-01-14 21:35:48.783] [jointLog] [info] done
# [2021-01-14 21:35:48.783] [jointLog] [info] Index contained 110,345 targets
# [2021-01-14 21:35:48.829] [jointLog] [info] Number of decoys : 0
#
#
#
#
# processed 0 Million fragments
# processed 1 Million fragments
# processed 1 Million fragments
# processed 2 Million fragments
# processed 2 Million fragments
# processed 3 Million fragments
# processed 3 Million fragments
# processed 4 Million fragments
# processed 4 Million fragments
# processed 5 Million fragments
# processed 5 Million fragments
# processed 6 Million fragments
# processed 6 Million fragments
# processed 7 Million fragments
# processed 7 Million fragments
# processed 8 Million fragments
# processed 8 Million fragments
# processed 9 Million fragments
# processed 9 Million fragments
# processed 10 Million fragments
# processed 10 Million fragments
# processed 11 Million fragments
# processed 11 Million fragments
# processed 12 Million fragments
# processed 12 Million fragments
# processed 13 Million fragments
# processed 13 Million fragments
# processed 14 Million fragments
# processed 14 Million fragments
# processed 15 Million fragments
# processed 15 Million fragments
# processed 16 Million fragments
# processed 16 Million fragments
# processed 17 Million fragments
# processed 18 Million fragments
# processed 18 Million fragments
# processed 19 Million fragments
# processed 19 Million fragments
# processed 20 Million fragments
# processed 20 Million fragments
# processed 21 Million fragments
# processed 21 Million fragments
# processed 22 Million fragments
# processed 22 Million fragments
# processed 23 Million fragments
# processed 23 Million fragments
# processed 24 Million fragments
# processed 24 Million fragments
# processed 25 Million fragments
# processed 25 Million fragments
# processed 26 Million fragments
# processed 26 Million fragments
# processed 27 Million fragments
# processed 27 Million fragments
# processed 28 Million fragments
# processed 28 Million fragments
# processed 29 Million fragments
# processed 29 Million fragments
# processed 29 Million fragments
# processed 30 Million fragments
# processed 30 Million fragments
# processed 31 Million fragments
# processed 31 Million fragments
# processed 32 Million fragments
# processed 32 Million fragments
# processed 33 Million fragments
# processed 33 Million fragments
# processed 34 Million fragments
# processed 34 Million fragments
# processed 35 Million fragments
# processed 35 Million fragments
# processed 36 Million fragments
[jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2021-01-14 21:38:04.257] [jointLog] [warning] Found 9152 reads with `N` in the UMI sequence and ignored the reads.
# Please report on github if this number is too large
# [2021-01-14 21:38:04.257] [jointLog] [info] finished sc_align()
#
# real	2m22.840s
# user	11m1.492s
# sys	0m7.160s

# %%
# %%bash
# INDIR="../../data/alevin_out/mouse-SRR8206317_v2" && \
# OUTDIR="../../data/alevin_out/mouse-SRR8206317_v2/generate" && \
# WHITELIST="../../reference/whitelist_10xv2.txt" && \
# time alevin-fry generate-permit-list \
# -d either \
# -i $INDIR \
# -o $OUTDIR \
# -b $WHITELIST
# Out:
# 2021-01-14 21:47:03 INFO paired : false, ref_count : 110,345, num_chunks : 13,346
# 2021-01-14 21:47:03 INFO read 2 file-level tags
# 2021-01-14 21:47:03 INFO read 2 read-level tags
# 2021-01-14 21:47:03 INFO read 1 alignemnt-level tags
# 2021-01-14 21:47:03 INFO File-level tag values FileTags { bclen: 16, umilen: 10 }
# 2021-01-14 21:47:12 INFO observed 66,727,614 reads in 13,346 chunks
# 2021-01-14 21:47:31 INFO total number of corrected barcodes : 667,197
#
# real	0m28.869s
# user	0m26.586s
# sys	0m2.219s

# %% [markdown]
# #### Note that `-m` needs to be set to limit memory

# %%
# %%bash
# INDIR="../../data/alevin_out/mouse-SRR8206317_v2/generate" && \
# RAD="../../data/alevin_out/mouse-SRR8206317_v2" && \
# time alevin-fry collate \
# -i $INDIR \
# -r $RAD \
# -t 8
# Out:
# 2021-01-14 21:54:19 INFO estimated that collation would require 2 passes over input.
# 2021-01-14 21:54:19 INFO executing multi-pass strategy.
# 2021-01-14 21:54:19 INFO expected_ori = Unknown
# 2021-01-14 21:54:19 INFO paired : false, ref_count : 110345, num_chunks : 13346, expected_ori : Unknown
# 2021-01-14 21:54:19 INFO read 2 file-level tags
# 2021-01-14 21:54:19 INFO read 2 read-level tags
# 2021-01-14 21:54:19 INFO read 1 alignemnt-level tags
# 2021-01-14 21:54:19 INFO File-level tag values FileTags { bclen: 16, umilen: 10 }
# 2021-01-14 21:56:41 INFO deserialized correction map of length : 64588762
# 2021-01-14 21:56:51 INFO
#
# total_allocated_records = 66290745, total_to_collate = 66290745
#
#
# 2021-01-14 21:56:51 INFO writing num output chunks (368907) to header
# 2021-01-14 21:56:51 INFO finished collating input rad file "../../data/alevin_out/mouse-SRR8206317_v2/map.rad".
#
# real	2m32.460s
# user	2m12.368s
# sys	1m19.087s

# %%
# %%bash
# INDIR="../../data/alevin_out/mouse-SRR8206317_v2/generate" && \
# OUTDIR="../../data/alevin_out/mouse-SRR8206317_v2/quant" && \
# T2G='../../reference/mouse-mm10/t2g.txt' && \
# time alevin-fry quant \
# --use-mtx \
# -i $INDIR \
# -o $OUTDIR \
# -m $T2G \
# -t 8
# Out:
# 2021-01-14 22:00:27 INFO paired : false, ref_count : 110345, num_chunks : 368907
# 2021-01-14 22:00:27 INFO tg-map contained 31053 genes mapping to 110345 transcripts.
# 2021-01-14 22:00:28 INFO read 2 file-level tags
# 2021-01-14 22:00:28 INFO read 2 read-level tags
# 2021-01-14 22:00:28 INFO read 1 alignemnt-level tags
# 2021-01-14 22:00:28 INFO File-level tag values FileTags { bclen: 16, umilen: 10 }
#
# real	2m27.922s
# user	19m16.735s
# sys	0m1.562s
