# %%
# !date
# Out:
# Thu Jan 14 14:19:40 PST 2021

# %% [markdown]
# # Salmon index

# %% [markdown]
# ## Human GRCh38

# %%
# %%bash
# time salmon index -i ../../reference/human-grch38/salmon-decoy \
#                   -d ../../reference/human-grch38/decoy/decoys.txt \
#                   -t ../../reference/human-grch38/decoy/gentrome.fa
# Out:
# Threads = 2
# Vertex length = 31
# Hash functions = 5
# Filter size = 2147483648
# Capacity = 2
# Files:
# ../../reference/human-grch38/salmon/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:2147483648
# Pass	Filling	Filtering
# 1	29	55
# 2	5	1
# True junctions count = 651945
# False junctions count = 1207369
# Hash table size = 1859314
# Candidate marks count = 8075425
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 5098137
# Edges construction time: 6
# --------------------------------------------------------------------------------
# Distinct junctions = 651945
#
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# Bitarray       593187584  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# ...

# %% [markdown]
# ## Human-mouse hg19-mm10

# %%
# %%bash
# time salmon index -i ../../reference/human_mouse-hg19_mm10/salmon-decoy \
#                   -d ../../reference/human_mouse-hg19_mm10/decoy/decoys.txt \
#                   -t ../../reference/human_mouse-hg19_mm10/decoy/gentrome.fa
# Out:
# Version Info: This is the most recent version of salmon.
# The file [../../reference/human_mouse-hg19_mm10/decoy/gentrome.fa] provided for the transcriptome does not appear to exist.
# real	0m5.028s
# user	0m0.005s
# sys	0m0.014s
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-1-efdf55bd1bb6> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'time salmon index -i ../../reference/human_mouse-hg19_mm10/salmon-decoy \\\n                  -d ../../reference/human_mouse-hg19_mm10/decoy/decoys.txt \\\n                  -t ../../reference/human_mouse-hg19_mm10/decoy/gentrome.fa\n')
#
# ~/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2360             with self.builtin_trap:
#    2361                 args = (magic_arg_s, cell)
# ...

# %% [markdown]
# ## Mouse mm10

# %% [markdown]
# full-decoy

# %%
# !time salmon index -i ../../reference/mouse-mm10/salmon-full-decoy \
                   -d ../../reference/mouse-mm10/full-decoy/decoys.txt \
                   -t ../../reference/mouse-mm10/full-decoy/gentrome.fa \
                   -p 10
# Out:
# Version Info: This is the most recent version of salmon.
# [2021-01-18 13:45:40.516] [jLog] [info] building index
# out : ../../reference/mouse-mm10/salmon-full-decoy
# [2021-01-18 13:45:40.517] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-01-18 13:45:42.138] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179520], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-18 13:45:42.138] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000179883], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-01-18 13:45:42.138] [puff::index::jointLog] [warning] Entry with header [ENSMUST00000195858], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# ...

# %% [markdown]
# ## Rat rnor6

# %%
# %%bash
# time salmon index -i ../../reference/rat-rnor6/salmon-decoy \
#                   -d ../../reference/rat-rnor6/decoy/decoys.txt \
#                   -t ../../reference/rat-rnor6/decoy/gentrome.fa
# Out:
# Threads = 2
# Vertex length = 31
# Hash functions = 5
# Filter size = 1073741824
# Capacity = 2
# Files:
# ../../reference/rat-rnor6/salmon/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:1073741824
# Pass	Filling	Filtering
# 1	10	20
# 2	1	0
# True junctions count = 89576
# False junctions count = 411257
# Hash table size = 500833
# Candidate marks count = 832925
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 357426
# Edges construction time: 2
# --------------------------------------------------------------------------------
# Distinct junctions = 89576
#
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# Bitarray       284664512  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# ...

# %% [markdown]
# ## Zebrafish dr82

# %%
# %%bash
# time salmon index -i ../../reference/zebrafish-dr82/salmon-decoy \
#                   -d ../../reference/zebrafish-dr82/decoy/decoys.txt \
#                   -t ../../reference/zebrafish-dr82/decoy/gentrome.fa
# Out:
# Threads = 2
# Vertex length = 31
# Hash functions = 5
# Filter size = 2147483648
# Capacity = 2
# Files:
# ../../reference/zebrafish-dr82/salmon/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:2147483648
# Pass	Filling	Filtering
# 1	15	25
# 2	2	0
# True junctions count = 195042
# False junctions count = 361019
# Hash table size = 556061
# Candidate marks count = 2174715
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 1509903
# Edges construction time: 2
# --------------------------------------------------------------------------------
# Distinct junctions = 195042
#
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# Bitarray       359708800  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# ...

# %% [markdown]
# ## Arabidopsis tair10

# %%
# %%bash
# time salmon index -i ../../reference/arabidopsis-tair10/salmon-decoy \
#                   -d ../../reference/arabidopsis-tair10/decoy/decoys.txt \
#                   -t ../../reference/arabidopsis-tair10/decoy/gentrome.fa
# Out:
# Threads = 2
# Vertex length = 31
# Hash functions = 5
# Filter size = 1073741824
# Capacity = 2
# Files:
# ../../reference/arabidopsis-tair10/salmon/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:1073741824
# Pass	Filling	Filtering
# 1	11	17
# 2	2	0
# True junctions count = 171142
# False junctions count = 305748
# Hash table size = 476890
# Candidate marks count = 1153119
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 744479
# Edges construction time: 2
# --------------------------------------------------------------------------------
# Distinct junctions = 171142
#
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# Bitarray       250257984  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# ...

# %% [markdown]
# ## Fly dm6

# %%
# %%bash
# time salmon index -i ../../reference/fly-dm6/salmon-decoy \
#                   -d ../../reference/fly-dm6/decoy/decoys.txt \
#                   -t ../../reference/fly-dm6/decoy/gentrome.fa
# Out:
# Threads = 2
# Vertex length = 31
# Hash functions = 5
# Filter size = 1073741824
# Capacity = 2
# Files:
# ../../reference/fly-dm6/salmon/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:1073741824
# Pass	Filling	Filtering
# 1	12	16
# 2	1	0
# True junctions count = 53037
# False junctions count = 67872
# Hash table size = 120909
# Candidate marks count = 446198
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 312196
# Edges construction time: 2
# --------------------------------------------------------------------------------
# Distinct junctions = 53037
#
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# Bitarray       184004288  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# ...

# %% [markdown]
# ## Worm ws260

# %%
# %%bash
# time salmon index -i ../../reference/worm-ws260/salmon-decoy \
#                   -d ../../reference/worm-ws260/decoy/decoys.txt \
#                   -t ../../reference/worm-ws260/decoy/gentrome.fa
# Out:
# Threads = 2
# Vertex length = 31
# Hash functions = 5
# Filter size = 536870912
# Capacity = 2
# Files:
# ../../reference/worm-ws260/salmon/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:536870912
# Pass	Filling	Filtering
# 1	7	12
# 2	1	0
# True junctions count = 47878
# False junctions count = 275510
# Hash table size = 323388
# Candidate marks count = 691481
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 227173
# Edges construction time: 1
# --------------------------------------------------------------------------------
# Distinct junctions = 47878
#
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# Bitarray       150057344  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# ...
